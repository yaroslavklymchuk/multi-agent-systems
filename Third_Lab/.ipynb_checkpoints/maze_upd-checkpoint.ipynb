# %%
import numpy as np

from algorithms import QLearning, ValueIteration
from environments import MazeEnv

import matplotlib.pyplot as plt
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.9.2)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
def get_results(env_size, num_episodes, num_portals, min_eps_rate, min_learning_rate, learning_rate,
                eps_rate, gamma, max_win_streak=100, 
                learning_rate_is_constant=False, eps_rate_is_constant=False, 
                debug=True, render_maze=True, recording_folder='./videos', enable_recording=True):
    
    env = MazeEnv(maze_size=env_size, num_portals=num_portals)
    
    qlearning = QLearning(env=env, num_episodes=num_episodes, min_epsilon_rate=min_eps_rate, 
                          min_learning_rate=min_learning_rate, learning_rate=learning_rate,
                          epsilon_rate=eps_rate, gamma=gamma, max_win_streak=max_win_streak,
                          learning_rate_is_constant=learning_rate_is_constant, 
                          epsilon_rate_is_constant=eps_rate_is_constant, debug=debug, render_maze=render_maze,
                          recording_folder=recording_folder, enable_recording=enable_recording
                         )
    
    total_rewards, total_streaks, steps_qty = qlearning.main()
    
    return total_rewards, total_streaks, steps_qty

# %%
total_rewards, total_streaks, steps_qty = get_results((5, 5), 500, 2, 1e-2, 0.5, 0.1, 0.5, 0.8)
# Out:
# /home/yaroslav/.local/lib/python3.9/site-packages/gym/logger.py:30: UserWarning: WARN: Trying to monitor an environment which has no 'spec' set. This usually means you did not create it via 'gym.make', and is recommended only for advanced users.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Episode = 0
# t = 76
# Explore rate: 0.800000
# Learning rate: 0.800000
# Streaks: 0
# Total reward: 0.408000
# Average Streaks: 0.000000
# Average Rewards: 0.408000
#
# Episode 0 finished after 76.000000 time steps with total reward = 0.408000 (streak 0).
#
# Episode = 1
# t = 159
# Explore rate: 0.800000
# Learning rate: 0.800000
# Streaks: 0
# Total reward: -0.020000
# Average Streaks: 0.000000
# Average Rewards: -0.010000
#
# Episode 1 finished after 159.000000 time steps with total reward = -0.020000 (streak 0).
#
# Episode = 2
# t = 340
# Explore rate: 0.800000
# Learning rate: 0.800000
# Streaks: 0
# Total reward: -0.564000
# Average Streaks: 0.000000
# Average Rewards: -0.188000
#
# Episode 2 finished after 340.000000 time steps with total reward = -0.564000 (streak 0).
#
# Episode = 3
# t = 39
# Explore rate: 0.800000
# Learning rate: 0.800000
# Streaks: 0
# Total reward: 0.784000
# Average Streaks: 0.000000
# Average Rewards: 0.196000
#
# Episode 3 finished after 39.000000 time steps with total reward = 0.784000 (streak 0).
#
# Episode = 4
# t = 167
# Explore rate: 0.795880
# Learning rate: 0.795880
# Streaks: 0
# Total reward: 0.116000
# Average Streaks: 0.000000
# Average Rewards: 0.023200
#
# Episode 4 finished after 167.000000 time steps with total reward = 0.116000 (streak 0).
#
# Episode = 5
# t = 82
# Explore rate: 0.698970
# Learning rate: 0.698970
# Streaks: 0
# Total reward: 0.456000
# Average Streaks: 0.000000
# Average Rewards: 0.076000
#
# Episode 5 finished after 82.000000 time steps with total reward = 0.456000 (streak 0).
#
# Episode = 6
# t = 263
# Explore rate: 0.619789
# Learning rate: 0.619789
# Streaks: 0
# Total reward: -0.508000
# Average Streaks: 0.000000
# Average Rewards: -0.072571
#
# Episode 6 finished after 263.000000 time steps with total reward = -0.508000 (streak 0).
#
# Episode = 7
# t = 16
# Explore rate: 0.552842
# Learning rate: 0.552842
# Streaks: 0
# Total reward: 0.864000
# Average Streaks: 0.000000
# Average Rewards: 0.108000
#
# Episode 7 finished after 16.000000 time steps with total reward = 0.864000 (streak 0).
#
# Episode = 8
# t = 13
# Explore rate: 0.494850
# Learning rate: 0.500000
# Streaks: 1
# Total reward: 0.900000
# Average Streaks: 0.111111
# Average Rewards: 0.100000
#
# Episode 8 finished after 13.000000 time steps with total reward = 0.900000 (streak 1).
#
# Episode = 9
# t = 15
# Explore rate: 0.443697
# Learning rate: 0.500000
# Streaks: 2
# Total reward: 0.880000
# Average Streaks: 0.200000
# Average Rewards: 0.088000
#
# Episode 9 finished after 15.000000 time steps with total reward = 0.880000 (streak 2).
#
# Episode = 10
# t = 23
# Explore rate: 0.397940
# Learning rate: 0.500000
# Streaks: 3
# Total reward: 0.812000
# Average Streaks: 0.272727
# Average Rewards: 0.073818
#
# Episode 10 finished after 23.000000 time steps with total reward = 0.812000 (streak 3).
#
# Episode = 11
# t = 32
# Explore rate: 0.356547
# Learning rate: 0.500000
# Streaks: 4
# Total reward: 0.800000
# Average Streaks: 0.333333
# Average Rewards: 0.066667
#
# Episode 11 finished after 32.000000 time steps with total reward = 0.800000 (streak 4).
#
# Episode = 12
# t = 14
# Explore rate: 0.318759
# Learning rate: 0.500000
# Streaks: 0
# Total reward: 0.908000
# Average Streaks: 0.000000
# Average Rewards: 0.069846
#
# Episode 12 finished after 14.000000 time steps with total reward = 0.908000 (streak 0).
#
# Episode = 13
# t = 16
# Explore rate: 0.283997
# Learning rate: 0.500000
# Streaks: 1
# Total reward: 0.900000
# Average Streaks: 0.071429
# Average Rewards: 0.064286
#
# Episode 13 finished after 16.000000 time steps with total reward = 0.900000 (streak 1).
#
# Episode = 14
# t = 20
# Explore rate: 0.251812
# Learning rate: 0.500000
# Streaks: 2
# Total reward: 0.884000
# Average Streaks: 0.133333
# Average Rewards: 0.058933
#
# Episode 14 finished after 20.000000 time steps with total reward = 0.884000 (streak 2).
#
# Episode = 15
# t = 19
# Explore rate: 0.221849
# Learning rate: 0.500000
# Streaks: 3
# Total reward: 0.888000
# Average Streaks: 0.187500
# Average Rewards: 0.055500
#
# Episode 15 finished after 19.000000 time steps with total reward = 0.888000 (streak 3).
#
# Episode = 16
# t = 12
# Explore rate: 0.193820
# Learning rate: 0.500000
# Streaks: 4
# Total reward: 0.904000
# Average Streaks: 0.235294
# Average Rewards: 0.053176
#
# Episode 16 finished after 12.000000 time steps with total reward = 0.904000 (streak 4).
#
# Episode = 17
# t = 14
# Explore rate: 0.167491
# Learning rate: 0.500000
# Streaks: 5
# Total reward: 0.896000
# Average Streaks: 0.277778
# Average Rewards: 0.049778
#
# Episode 17 finished after 14.000000 time steps with total reward = 0.896000 (streak 5).
#
# Episode = 18
# t = 12
# Explore rate: 0.142668
# Learning rate: 0.500000
# Streaks: 6
# Total reward: 0.916000
# Average Streaks: 0.315789
# Average Rewards: 0.048211
#
# Episode 18 finished after 12.000000 time steps with total reward = 0.916000 (streak 6).
#
# Episode = 19
# t = 13
# Explore rate: 0.119186
# Learning rate: 0.500000
# Streaks: 7
# Total reward: 0.888000
# Average Streaks: 0.350000
# Average Rewards: 0.044400
#
# Episode 19 finished after 13.000000 time steps with total reward = 0.888000 (streak 7).
#
# Episode = 20
# t = 12
# Explore rate: 0.096910
# Learning rate: 0.500000
# Streaks: 8
# Total reward: 0.916000
# Average Streaks: 0.380952
# Average Rewards: 0.043619
#
# Episode 20 finished after 12.000000 time steps with total reward = 0.916000 (streak 8).
#
# Episode = 21
# t = 12
# Explore rate: 0.075721
# Learning rate: 0.500000
# Streaks: 9
# Total reward: 0.904000
# Average Streaks: 0.409091
# Average Rewards: 0.041091
#
# Episode 21 finished after 12.000000 time steps with total reward = 0.904000 (streak 9).
#
# Episode = 22
# t = 13
# Explore rate: 0.055517
# Learning rate: 0.500000
# Streaks: 10
# Total reward: 0.912000
# Average Streaks: 0.434783
# Average Rewards: 0.039652
#
# Episode 22 finished after 13.000000 time steps with total reward = 0.912000 (streak 10).
#
# Episode = 23
# t = 11
# Explore rate: 0.036212
# Learning rate: 0.500000
# Streaks: 11
# Total reward: 0.920000
# Average Streaks: 0.458333
# Average Rewards: 0.038333
#
# Episode 23 finished after 11.000000 time steps with total reward = 0.920000 (streak 11).
#
# Episode = 24
# t = 11
# Explore rate: 0.017729
# Learning rate: 0.500000
# Streaks: 12
# Total reward: 0.920000
# Average Streaks: 0.480000
# Average Rewards: 0.036800
#
# Episode 24 finished after 11.000000 time steps with total reward = 0.920000 (streak 12).
#
# Episode = 25
# t = 12
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 13
# Total reward: 0.916000
# Average Streaks: 0.500000
# Average Rewards: 0.035231
#
# Episode 25 finished after 12.000000 time steps with total reward = 0.916000 (streak 13).
#
# Episode = 26
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 14
# Total reward: 0.920000
# Average Streaks: 0.518519
# Average Rewards: 0.034074
#
# Episode 26 finished after 11.000000 time steps with total reward = 0.920000 (streak 14).
#
# Episode = 27
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 15
# Total reward: 0.920000
# Average Streaks: 0.535714
# Average Rewards: 0.032857
#
# Episode 27 finished after 11.000000 time steps with total reward = 0.920000 (streak 15).
#
# Episode = 28
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 16
# Total reward: 0.920000
# Average Streaks: 0.551724
# Average Rewards: 0.031724
#
# Episode 28 finished after 11.000000 time steps with total reward = 0.920000 (streak 16).
#
# Episode = 29
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 17
# Total reward: 0.920000
# Average Streaks: 0.566667
# Average Rewards: 0.030667
#
# Episode 29 finished after 11.000000 time steps with total reward = 0.920000 (streak 17).
#
# Episode = 30
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 18
# Total reward: 0.920000
# Average Streaks: 0.580645
# Average Rewards: 0.029677
#
# Episode 30 finished after 11.000000 time steps with total reward = 0.920000 (streak 18).
#
# Episode = 31
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 19
# Total reward: 0.920000
# Average Streaks: 0.593750
# Average Rewards: 0.028750
#
# Episode 31 finished after 11.000000 time steps with total reward = 0.920000 (streak 19).
#
# Episode = 32
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 20
# Total reward: 0.920000
# Average Streaks: 0.606061
# Average Rewards: 0.027879
#
# Episode 32 finished after 11.000000 time steps with total reward = 0.920000 (streak 20).
#
# Episode = 33
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 21
# Total reward: 0.920000
# Average Streaks: 0.617647
# Average Rewards: 0.027059
#
# Episode 33 finished after 11.000000 time steps with total reward = 0.920000 (streak 21).
# Episode = 34
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 22
# Total reward: 0.920000
# Average Streaks: 0.628571
# Average Rewards: 0.026286
#
# Episode 34 finished after 11.000000 time steps with total reward = 0.920000 (streak 22).
#
# Episode = 35
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 23
# Total reward: 0.920000
# Average Streaks: 0.638889
# Average Rewards: 0.025556
#
# Episode 35 finished after 11.000000 time steps with total reward = 0.920000 (streak 23).
#
# Episode = 36
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 24
# Total reward: 0.920000
# Average Streaks: 0.648649
# Average Rewards: 0.024865
#
# Episode 36 finished after 11.000000 time steps with total reward = 0.920000 (streak 24).
#
# Episode = 37
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 25
# Total reward: 0.920000
# Average Streaks: 0.657895
# Average Rewards: 0.024211
#
# Episode 37 finished after 11.000000 time steps with total reward = 0.920000 (streak 25).
#
# Episode = 38
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 26
# Total reward: 0.920000
# Average Streaks: 0.666667
# Average Rewards: 0.023590
#
# Episode 38 finished after 11.000000 time steps with total reward = 0.920000 (streak 26).
#
# Episode = 39
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 27
# Total reward: 0.920000
# Average Streaks: 0.675000
# Average Rewards: 0.023000
#
# Episode 39 finished after 11.000000 time steps with total reward = 0.920000 (streak 27).
#
# Episode = 40
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 28
# Total reward: 0.920000
# Average Streaks: 0.682927
# Average Rewards: 0.022439
#
# Episode 40 finished after 11.000000 time steps with total reward = 0.920000 (streak 28).
#
# Episode = 41
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 29
# Total reward: 0.920000
# Average Streaks: 0.690476
# Average Rewards: 0.021905
#
# Episode 41 finished after 11.000000 time steps with total reward = 0.920000 (streak 29).
#
# Episode = 42
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 30
# Total reward: 0.920000
# Average Streaks: 0.697674
# Average Rewards: 0.021395
#
# Episode 42 finished after 11.000000 time steps with total reward = 0.920000 (streak 30).
#
# Episode = 43
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 31
# Total reward: 0.920000
# Average Streaks: 0.704545
# Average Rewards: 0.020909
#
# Episode 43 finished after 11.000000 time steps with total reward = 0.920000 (streak 31).
#
# Episode = 44
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 32
# Total reward: 0.920000
# Average Streaks: 0.711111
# Average Rewards: 0.020444
#
# Episode 44 finished after 11.000000 time steps with total reward = 0.920000 (streak 32).
#
# Episode = 45
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 33
# Total reward: 0.920000
# Average Streaks: 0.717391
# Average Rewards: 0.020000
#
# Episode 45 finished after 11.000000 time steps with total reward = 0.920000 (streak 33).
#
# Episode = 46
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 34
# Total reward: 0.920000
# Average Streaks: 0.723404
# Average Rewards: 0.019574
#
# Episode 46 finished after 11.000000 time steps with total reward = 0.920000 (streak 34).
#
# Episode = 47
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 35
# Total reward: 0.920000
# Average Streaks: 0.729167
# Average Rewards: 0.019167
#
# Episode 47 finished after 11.000000 time steps with total reward = 0.920000 (streak 35).
#
# Episode = 48
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 36
# Total reward: 0.920000
# Average Streaks: 0.734694
# Average Rewards: 0.018776
#
# Episode 48 finished after 11.000000 time steps with total reward = 0.920000 (streak 36).
#
# Episode = 49
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 37
# Total reward: 0.920000
# Average Streaks: 0.740000
# Average Rewards: 0.018400
#
# Episode 49 finished after 11.000000 time steps with total reward = 0.920000 (streak 37).
#
# Episode = 50
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 38
# Total reward: 0.920000
# Average Streaks: 0.745098
# Average Rewards: 0.018039
#
# Episode 50 finished after 11.000000 time steps with total reward = 0.920000 (streak 38).
#
# Episode = 51
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 39
# Total reward: 0.920000
# Average Streaks: 0.750000
# Average Rewards: 0.017692
#
# Episode 51 finished after 11.000000 time steps with total reward = 0.920000 (streak 39).
#
# Episode = 52
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 40
# Total reward: 0.920000
# Average Streaks: 0.754717
# Average Rewards: 0.017358
#
# Episode 52 finished after 11.000000 time steps with total reward = 0.920000 (streak 40).
#
# Episode = 53
# t = 12
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 41
# Total reward: 0.916000
# Average Streaks: 0.759259
# Average Rewards: 0.016963
#
# Episode 53 finished after 12.000000 time steps with total reward = 0.916000 (streak 41).
#
# Episode = 54
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 42
# Total reward: 0.920000
# Average Streaks: 0.763636
# Average Rewards: 0.016727
#
# Episode 54 finished after 11.000000 time steps with total reward = 0.920000 (streak 42).
#
# Episode = 55
# t = 12
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 43
# Total reward: 0.904000
# Average Streaks: 0.767857
# Average Rewards: 0.016143
#
# Episode 55 finished after 12.000000 time steps with total reward = 0.904000 (streak 43).
#
# Episode = 56
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 44
# Total reward: 0.920000
# Average Streaks: 0.771930
# Average Rewards: 0.016140
#
# Episode 56 finished after 11.000000 time steps with total reward = 0.920000 (streak 44).
#
# Episode = 57
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 45
# Total reward: 0.920000
# Average Streaks: 0.775862
# Average Rewards: 0.015862
#
# Episode 57 finished after 11.000000 time steps with total reward = 0.920000 (streak 45).
#
# Episode = 58
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 46
# Total reward: 0.920000
# Average Streaks: 0.779661
# Average Rewards: 0.015593
#
# Episode 58 finished after 11.000000 time steps with total reward = 0.920000 (streak 46).
#
# Episode = 59
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 47
# Total reward: 0.920000
# Average Streaks: 0.783333
# Average Rewards: 0.015333
#
# Episode 59 finished after 11.000000 time steps with total reward = 0.920000 (streak 47).
#
# Episode = 60
# t = 15
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 48
# Total reward: 0.880000
# Average Streaks: 0.786885
# Average Rewards: 0.014426
#
# Episode 60 finished after 15.000000 time steps with total reward = 0.880000 (streak 48).
#
# Episode = 61
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 49
# Total reward: 0.920000
# Average Streaks: 0.790323
# Average Rewards: 0.014839
#
# Episode 61 finished after 11.000000 time steps with total reward = 0.920000 (streak 49).
#
# Episode = 62
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 50
# Total reward: 0.920000
# Average Streaks: 0.793651
# Average Rewards: 0.014603
#
# Episode 62 finished after 11.000000 time steps with total reward = 0.920000 (streak 50).
#
# Episode = 63
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 51
# Total reward: 0.920000
# Average Streaks: 0.796875
# Average Rewards: 0.014375
#
# Episode 63 finished after 11.000000 time steps with total reward = 0.920000 (streak 51).
#
# Episode = 64
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 52
# Total reward: 0.920000
# Average Streaks: 0.800000
# Average Rewards: 0.014154
#
# Episode 64 finished after 11.000000 time steps with total reward = 0.920000 (streak 52).
#
# Episode = 65
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 53
# Total reward: 0.920000
# Average Streaks: 0.803030
# Average Rewards: 0.013939
#
# Episode 65 finished after 11.000000 time steps with total reward = 0.920000 (streak 53).
#
# Episode = 66
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 54
# Total reward: 0.920000
# Average Streaks: 0.805970
# Average Rewards: 0.013731
#
# Episode 66 finished after 11.000000 time steps with total reward = 0.920000 (streak 54).
#
# Episode = 67
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 55
# Total reward: 0.920000
# Average Streaks: 0.808824
# Average Rewards: 0.013529
#
# Episode 67 finished after 11.000000 time steps with total reward = 0.920000 (streak 55).
# Episode = 68
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 56
# Total reward: 0.920000
# Average Streaks: 0.811594
# Average Rewards: 0.013333
#
# Episode 68 finished after 11.000000 time steps with total reward = 0.920000 (streak 56).
#
# Episode = 69
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 57
# Total reward: 0.920000
# Average Streaks: 0.814286
# Average Rewards: 0.013143
#
# Episode 69 finished after 11.000000 time steps with total reward = 0.920000 (streak 57).
#
# Episode = 70
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 58
# Total reward: 0.920000
# Average Streaks: 0.816901
# Average Rewards: 0.012958
#
# Episode 70 finished after 11.000000 time steps with total reward = 0.920000 (streak 58).
#
# Episode = 71
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 59
# Total reward: 0.920000
# Average Streaks: 0.819444
# Average Rewards: 0.012778
#
# Episode 71 finished after 11.000000 time steps with total reward = 0.920000 (streak 59).
#
# Episode = 72
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 60
# Total reward: 0.920000
# Average Streaks: 0.821918
# Average Rewards: 0.012603
#
# Episode 72 finished after 11.000000 time steps with total reward = 0.920000 (streak 60).
#
# Episode = 73
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 61
# Total reward: 0.920000
# Average Streaks: 0.824324
# Average Rewards: 0.012432
#
# Episode 73 finished after 11.000000 time steps with total reward = 0.920000 (streak 61).
#
# Episode = 74
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 62
# Total reward: 0.920000
# Average Streaks: 0.826667
# Average Rewards: 0.012267
#
# Episode 74 finished after 11.000000 time steps with total reward = 0.920000 (streak 62).
#
# Episode = 75
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 63
# Total reward: 0.920000
# Average Streaks: 0.828947
# Average Rewards: 0.012105
#
# Episode 75 finished after 11.000000 time steps with total reward = 0.920000 (streak 63).
#
# Episode = 76
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 64
# Total reward: 0.920000
# Average Streaks: 0.831169
# Average Rewards: 0.011948
#
# Episode 76 finished after 11.000000 time steps with total reward = 0.920000 (streak 64).
#
# Episode = 77
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 65
# Total reward: 0.920000
# Average Streaks: 0.833333
# Average Rewards: 0.011795
#
# Episode 77 finished after 11.000000 time steps with total reward = 0.920000 (streak 65).
#
# Episode = 78
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 66
# Total reward: 0.920000
# Average Streaks: 0.835443
# Average Rewards: 0.011646
#
# Episode 78 finished after 11.000000 time steps with total reward = 0.920000 (streak 66).
#
# Episode = 79
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 67
# Total reward: 0.920000
# Average Streaks: 0.837500
# Average Rewards: 0.011500
#
# Episode 79 finished after 11.000000 time steps with total reward = 0.920000 (streak 67).
#
# Episode = 80
# t = 13
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 68
# Total reward: 0.912000
# Average Streaks: 0.839506
# Average Rewards: 0.011259
#
# Episode 80 finished after 13.000000 time steps with total reward = 0.912000 (streak 68).
#
# Episode = 81
# t = 12
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 69
# Total reward: 0.916000
# Average Streaks: 0.841463
# Average Rewards: 0.011171
#
# Episode 81 finished after 12.000000 time steps with total reward = 0.916000 (streak 69).
#
# Episode = 82
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 70
# Total reward: 0.920000
# Average Streaks: 0.843373
# Average Rewards: 0.011084
#
# Episode 82 finished after 11.000000 time steps with total reward = 0.920000 (streak 70).
#
# Episode = 83
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 71
# Total reward: 0.920000
# Average Streaks: 0.845238
# Average Rewards: 0.010952
#
# Episode 83 finished after 11.000000 time steps with total reward = 0.920000 (streak 71).
#
# Episode = 84
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 72
# Total reward: 0.920000
# Average Streaks: 0.847059
# Average Rewards: 0.010824
#
# Episode 84 finished after 11.000000 time steps with total reward = 0.920000 (streak 72).
#
# Episode = 85
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 73
# Total reward: 0.920000
# Average Streaks: 0.848837
# Average Rewards: 0.010698
#
# Episode 85 finished after 11.000000 time steps with total reward = 0.920000 (streak 73).
#
# Episode = 86
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 74
# Total reward: 0.920000
# Average Streaks: 0.850575
# Average Rewards: 0.010575
#
# Episode 86 finished after 11.000000 time steps with total reward = 0.920000 (streak 74).
#
# Episode = 87
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 75
# Total reward: 0.920000
# Average Streaks: 0.852273
# Average Rewards: 0.010455
#
# Episode 87 finished after 11.000000 time steps with total reward = 0.920000 (streak 75).
#
# Episode = 88
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 76
# Total reward: 0.920000
# Average Streaks: 0.853933
# Average Rewards: 0.010337
#
# Episode 88 finished after 11.000000 time steps with total reward = 0.920000 (streak 76).
#
# Episode = 89
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 77
# Total reward: 0.920000
# Average Streaks: 0.855556
# Average Rewards: 0.010222
#
# Episode 89 finished after 11.000000 time steps with total reward = 0.920000 (streak 77).
#
# Episode = 90
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 78
# Total reward: 0.920000
# Average Streaks: 0.857143
# Average Rewards: 0.010110
#
# Episode 90 finished after 11.000000 time steps with total reward = 0.920000 (streak 78).
#
# Episode = 91
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 79
# Total reward: 0.920000
# Average Streaks: 0.858696
# Average Rewards: 0.010000
#
# Episode 91 finished after 11.000000 time steps with total reward = 0.920000 (streak 79).
#
# Episode = 92
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 80
# Total reward: 0.920000
# Average Streaks: 0.860215
# Average Rewards: 0.009892
#
# Episode 92 finished after 11.000000 time steps with total reward = 0.920000 (streak 80).
#
# Episode = 93
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 81
# Total reward: 0.920000
# Average Streaks: 0.861702
# Average Rewards: 0.009787
#
# Episode 93 finished after 11.000000 time steps with total reward = 0.920000 (streak 81).
#
# Episode = 94
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 82
# Total reward: 0.920000
# Average Streaks: 0.863158
# Average Rewards: 0.009684
#
# Episode 94 finished after 11.000000 time steps with total reward = 0.920000 (streak 82).
#
# Episode = 95
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 83
# Total reward: 0.920000
# Average Streaks: 0.864583
# Average Rewards: 0.009583
#
# Episode 95 finished after 11.000000 time steps with total reward = 0.920000 (streak 83).
#
# Episode = 96
# t = 12
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 84
# Total reward: 0.916000
# Average Streaks: 0.865979
# Average Rewards: 0.009443
#
# Episode 96 finished after 12.000000 time steps with total reward = 0.916000 (streak 84).
#
# Episode = 97
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 85
# Total reward: 0.920000
# Average Streaks: 0.867347
# Average Rewards: 0.009388
#
# Episode 97 finished after 11.000000 time steps with total reward = 0.920000 (streak 85).
#
# Episode = 98
# t = 13
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 86
# Total reward: 0.912000
# Average Streaks: 0.868687
# Average Rewards: 0.009212
#
# Episode 98 finished after 13.000000 time steps with total reward = 0.912000 (streak 86).
#
# Episode = 99
# t = 12
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 87
# Total reward: 0.916000
# Average Streaks: 0.870000
# Average Rewards: 0.009160
#
# Episode 99 finished after 12.000000 time steps with total reward = 0.916000 (streak 87).
#
# Episode = 100
# t = 13
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 88
# Total reward: 0.912000
# Average Streaks: 0.871287
# Average Rewards: 0.009030
#
# Episode 100 finished after 13.000000 time steps with total reward = 0.912000 (streak 88).
#
# Episode = 101
# t = 13
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 89
# Total reward: 0.912000
# Average Streaks: 0.872549
# Average Rewards: 0.008941
#
# Episode 101 finished after 13.000000 time steps with total reward = 0.912000 (streak 89).
# Episode = 102
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 90
# Total reward: 0.920000
# Average Streaks: 0.873786
# Average Rewards: 0.008932
#
# Episode 102 finished after 11.000000 time steps with total reward = 0.920000 (streak 90).
#
# Episode = 103
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 91
# Total reward: 0.920000
# Average Streaks: 0.875000
# Average Rewards: 0.008846
#
# Episode 103 finished after 11.000000 time steps with total reward = 0.920000 (streak 91).
#
# Episode = 104
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 92
# Total reward: 0.920000
# Average Streaks: 0.876190
# Average Rewards: 0.008762
#
# Episode 104 finished after 11.000000 time steps with total reward = 0.920000 (streak 92).
#
# Episode = 105
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 93
# Total reward: 0.920000
# Average Streaks: 0.877358
# Average Rewards: 0.008679
#
# Episode 105 finished after 11.000000 time steps with total reward = 0.920000 (streak 93).
#
# Episode = 106
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 94
# Total reward: 0.920000
# Average Streaks: 0.878505
# Average Rewards: 0.008598
#
# Episode 106 finished after 11.000000 time steps with total reward = 0.920000 (streak 94).
#
# Episode = 107
# t = 12
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 95
# Total reward: 0.916000
# Average Streaks: 0.879630
# Average Rewards: 0.008481
#
# Episode 107 finished after 12.000000 time steps with total reward = 0.916000 (streak 95).
#
# Episode = 108
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 96
# Total reward: 0.920000
# Average Streaks: 0.880734
# Average Rewards: 0.008440
#
# Episode 108 finished after 11.000000 time steps with total reward = 0.920000 (streak 96).
#
# Episode = 109
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 97
# Total reward: 0.920000
# Average Streaks: 0.881818
# Average Rewards: 0.008364
#
# Episode 109 finished after 11.000000 time steps with total reward = 0.920000 (streak 97).
#
# Episode = 110
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 98
# Total reward: 0.920000
# Average Streaks: 0.882883
# Average Rewards: 0.008288
#
# Episode 110 finished after 11.000000 time steps with total reward = 0.920000 (streak 98).
#
# Episode = 111
# t = 17
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 99
# Total reward: 0.848000
# Average Streaks: 0.883929
# Average Rewards: 0.007571
#
# Episode 111 finished after 17.000000 time steps with total reward = 0.848000 (streak 99).
#
# Episode = 112
# t = 11
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 100
# Total reward: 0.920000
# Average Streaks: 0.884956
# Average Rewards: 0.008142
#
# Episode 112 finished after 11.000000 time steps with total reward = 0.920000 (streak 100).

# %%
len(total_rewards)
# Out:
# 112

# %%
plt.figure(figsize=(10, 5))

plt.plot(total_rewards);

# %%
np.mean(total_rewards)
# Out:
# 0.8619642857142856

# %%
def get_results_iteration(env_size, num_portals, gamma, epsilon, small, make_action_proba=1, max_win_streak=100, 
                debug=True, render_maze=True, recording_folder='./videos', enable_recording=True):
    
    env = MazeEnv(maze_size=env_size, num_portals=num_portals)
    
    viter = ValueIteration(env=env, gamma=gamma, epsilon=epsilon, small=small,make_action_proba=make_action_proba,
                               max_win_streak=max_win_streak, debug=debug, render_maze=render_maze,
                               recording_folder=recording_folder, enable_recording=enable_recording
                              )
    
    total_rewards, total_streaks, steps_qty = viter.main()
    
    return total_rewards, total_streaks, steps_qty

# %%
total_rewards, total_streaks, steps_qty = get_results_iteration((10, 10), 2, 0.9, 0.1, 0.01)
# Out:
# (0, 0) ['E', 'S']
# (0, 1) ['N', 'S']
# (0, 2) ['N', 'S']
# (0, 3) ['N', 'E', 'S']
# (0, 4) ['N', 'E']
# (0, 5) ['S']
# (0, 6) ['N', 'E', 'S']
# (0, 7) ['N', 'S']
# (0, 8) ['N', 'E', 'S']
# (0, 9) ['N', 'E']
# (1, 0) ['E', 'W']
# (1, 1) ['E', 'S']
# (1, 2) ['N', 'S']
# (1, 3) ['N', 'W']
# (1, 4) ['S', 'W']
# (1, 5) ['N', 'E']
# (1, 6) ['W']
# (1, 7) ['E', 'S']
# (1, 8) ['N', 'W']
# (1, 9) ['E', 'W']
# (2, 0) ['W']
# (2, 1) ['E', 'W']
# (2, 2) ['E', 'S']
# (2, 3) ['N', 'E']
# (2, 4) ['E', 'S']
# (2, 5) ['N', 'W']
# (2, 6) ['E', 'S']
# (2, 7) ['N', 'W']
# (2, 8) ['E', 'S']
# (2, 9) ['N', 'W']
# (3, 0) ['E', 'S']
# (3, 1) ['N', 'W']
# (3, 2) ['W']
# (3, 3) ['S', 'W']
# (3, 4) ['N', 'S', 'W']
# (3, 5) ['N', 'E']
# (3, 6) ['E', 'S', 'W']
# (3, 7) ['N', 'E']
# (3, 8) ['S', 'W']
# (3, 9) ['N', 'E']
# (4, 0) ['E', 'W']
# (4, 1) ['E', 'S']
# (4, 2) ['N', 'S']
# (4, 3) ['N', 'S']
# (4, 4) ['N', 'E']
# (4, 5) ['E', 'W']
# (4, 6) ['E', 'W']
# (4, 7) ['E', 'W']
# (4, 8) ['E', 'S']
# (4, 9) ['N', 'W']
# (5, 0) ['E', 'S', 'W']
# (5, 1) ['N', 'W']
# (5, 2) ['E', 'S']
# (5, 3) ['N', 'S']
# (5, 4) ['N', 'W']
# (5, 5) ['E', 'W']
# (5, 6) ['W']
# (5, 7) ['E', 'W']
# (5, 8) ['S', 'W']
# (5, 9) ['N', 'E']
# (6, 0) ['S', 'W']
# (6, 1) ['N', 'E']
# (6, 2) ['S', 'W']
# (6, 3) ['N', 'S']
# (6, 4) ['N', 'E']
# (6, 5) ['S', 'W']
# (6, 6) ['N', 'S']
# (6, 7) ['N', 'S', 'W']
# (6, 8) ['N']
# (6, 9) ['E', 'W']
# (7, 0) ['E']
# (7, 1) ['S', 'W']
# (7, 2) ['N', 'S']
# (7, 3) ['N', 'E']
# (7, 4) ['S', 'W']
# (7, 5) ['N', 'S']
# (7, 6) ['N', 'S']
# (7, 7) ['N', 'S']
# (7, 8) ['N', 'E']
# (7, 9) ['E', 'W']
# (8, 0) ['E', 'W']
# (8, 1) ['E', 'S']
# (8, 2) ['N', 'E']
# (8, 3) ['S', 'W']
# (8, 4) ['N', 'E']
# (8, 5) ['S']
# (8, 6) ['N', 'S']
# (8, 7) ['N', 'E']
# (8, 8) ['S', 'W']
# (8, 9) ['N', 'W']
# (9, 0) ['S', 'W']
# (9, 1) ['N', 'W']
# (9, 2) ['S', 'W']
# (9, 3) ['N', 'S']
# (9, 4) ['N', 'S', 'W']
# (9, 5) ['N', 'S']
# (9, 6) ['N', 'S']
# (9, 7) ['N', 'S', 'W']
# (9, 8) ['N', 'S']
# (9, 9) ['N']
# (0, 0) ['E', 'S']
# (0, 1) ['N', 'S']
# (0, 2) ['N', 'S']
# (0, 3) ['N', 'E', 'S']
# (0, 4) ['N', 'E']
# (0, 5) ['S']
# (0, 6) ['N', 'E', 'S']
# (0, 7) ['N', 'S']
# (0, 8) ['N', 'E', 'S']
# (0, 9) ['N', 'E']
# (1, 0) ['E', 'W']
# (1, 1) ['E', 'S']
# (1, 2) ['N', 'S']
# (1, 3) ['N', 'W']
# (1, 4) ['S', 'W']
# (1, 5) ['N', 'E']
# (1, 6) ['W']
# (1, 7) ['E', 'S']
# (1, 8) ['N', 'W']
# (1, 9) ['E', 'W']
# (2, 0) ['W']
# (2, 1) ['E', 'W']
# (2, 2) ['E', 'S']
# (2, 3) ['N', 'E']
# (2, 4) ['E', 'S']
# (2, 5) ['N', 'W']
# (2, 6) ['E', 'S']
# (2, 7) ['N', 'W']
# (2, 8) ['E', 'S']
# (2, 9) ['N', 'W']
# (3, 0) ['E', 'S']
# (3, 1) ['N', 'W']
# (3, 2) ['W']
# (3, 3) ['S', 'W']
# (3, 4) ['N', 'S', 'W']
# (3, 5) ['N', 'E']
# (3, 6) ['E', 'S', 'W']
# (3, 7) ['N', 'E']
# (3, 8) ['S', 'W']
# (3, 9) ['N', 'E']
# (4, 0) ['E', 'W']
# (4, 1) ['E', 'S']
# (4, 2) ['N', 'S']
# (4, 3) ['N', 'S']
# (4, 4) ['N', 'E']
# (4, 5) ['E', 'W']
# (4, 6) ['E', 'W']
# (4, 7) ['E', 'W']
# (4, 8) ['E', 'S']
# (4, 9) ['N', 'W']
# (5, 0) ['E', 'S', 'W']
# (5, 1) ['N', 'W']
# (5, 2) ['E', 'S']
# (5, 3) ['N', 'S']
# (5, 4) ['N', 'W']
# (5, 5) ['E', 'W']
# (5, 6) ['W']
# (5, 7) ['E', 'W']
# (5, 8) ['S', 'W']
# (5, 9) ['N', 'E']
# (6, 0) ['S', 'W']
# (6, 1) ['N', 'E']
# (6, 2) ['S', 'W']
# (6, 3) ['N', 'S']
# (6, 4) ['N', 'E']
# (6, 5) ['S', 'W']
# (6, 6) ['N', 'S']
# (6, 7) ['N', 'S', 'W']
# (6, 8) ['N']
# (6, 9) ['E', 'W']
# (7, 0) ['E']
# (7, 1) ['S', 'W']
# (7, 2) ['N', 'S']
# (7, 3) ['N', 'E']
# (7, 4) ['S', 'W']
# (7, 5) ['N', 'S']
# (7, 6) ['N', 'S']
# (7, 7) ['N', 'S']
# (7, 8) ['N', 'E']
# (7, 9) ['E', 'W']
# (8, 0) ['E', 'W']
# (8, 1) ['E', 'S']
# (8, 2) ['N', 'E']
# (8, 3) ['S', 'W']
# (8, 4) ['N', 'E']
# (8, 5) ['S']
# (8, 6) ['N', 'S']
# (8, 7) ['N', 'E']
# (8, 8) ['S', 'W']
# (8, 9) ['N', 'W']
# (9, 0) ['S', 'W']
# (9, 1) ['N', 'W']
# (9, 2) ['S', 'W']
# (9, 3) ['N', 'S']
# (9, 4) ['N', 'S', 'W']
# (9, 5) ['N', 'S']
# (9, 6) ['N', 'S']
# (9, 7) ['N', 'S', 'W']
# (9, 8) ['N', 'S']
# (0, 0) ['E', 'S']
# (0, 1) ['N', 'S']
# (0, 2) ['N', 'S']
# (0, 3) ['N', 'E', 'S']
# (0, 4) ['N', 'E']
# (0, 5) ['S']
# (0, 6) ['N', 'E', 'S']
# (0, 7) ['N', 'S']
# (0, 8) ['N', 'E', 'S']
# (0, 9) ['N', 'E']
# (1, 0) ['E', 'W']
# (1, 1) ['E', 'S']
# (1, 2) ['N', 'S']
# (1, 3) ['N', 'W']
# (1, 4) ['S', 'W']
# (1, 5) ['N', 'E']
# (1, 6) ['W']
# (1, 7) ['E', 'S']
# (1, 8) ['N', 'W']
# (1, 9) ['E', 'W']
# (2, 0) ['W']
# (2, 1) ['E', 'W']
# (2, 2) ['E', 'S']
# (2, 3) ['N', 'E']
# (2, 4) ['E', 'S']
# (2, 5) ['N', 'W']
# (2, 6) ['E', 'S']
# (2, 7) ['N', 'W']
# (2, 8) ['E', 'S']
# (2, 9) ['N', 'W']
# (3, 0) ['E', 'S']
# (3, 1) ['N', 'W']
# (3, 2) ['W']
# (3, 3) ['S', 'W']
# (3, 4) ['N', 'S', 'W']
# (3, 5) ['N', 'E']
# (3, 6) ['E', 'S', 'W']
# (3, 7) ['N', 'E']
# (3, 8) ['S', 'W']
# (3, 9) ['N', 'E']
# (4, 0) ['E', 'W']
# (4, 1) ['E', 'S']
# (4, 2) ['N', 'S']
# (4, 3) ['N', 'S']
# (4, 4) ['N', 'E']
# (4, 5) ['E', 'W']
# (4, 6) ['E', 'W']
# (4, 7) ['E', 'W']
# (4, 8) ['E', 'S']
# (4, 9) ['N', 'W']
# (5, 0) ['E', 'S', 'W']
# (5, 1) ['N', 'W']
# (5, 2) ['E', 'S']
# (5, 3) ['N', 'S']
# (5, 4) ['N', 'W']
# (5, 5) ['E', 'W']
# (5, 6) ['W']
# (5, 7) ['E', 'W']
# (5, 8) ['S', 'W']
# (5, 9) ['N', 'E']
# (6, 0) ['S', 'W']
# (6, 1) ['N', 'E']
# (6, 2) ['S', 'W']
# (6, 3) ['N', 'S']
# (6, 4) ['N', 'E']
# (6, 5) ['S', 'W']
# (6, 6) ['N', 'S']
# (6, 7) ['N', 'S', 'W']
# (6, 8) ['N']
# (6, 9) ['E', 'W']
# (7, 0) ['E']
# (7, 1) ['S', 'W']
# (7, 2) ['N', 'S']
# (7, 3) ['N', 'E']
# (7, 4) ['S', 'W']
# (7, 5) ['N', 'S']
# (7, 6) ['N', 'S']
# (7, 7) ['N', 'S']
# (7, 8) ['N', 'E']
# (7, 9) ['E', 'W']
# (8, 0) ['E', 'W']
# (8, 1) ['E', 'S']
# (8, 2) ['N', 'E']
# (8, 3) ['S', 'W']
# (8, 4) ['N', 'E']
# (8, 5) ['S']
# (8, 6) ['N', 'S']
# (8, 7) ['N', 'E']
# (8, 8) ['S', 'W']
# (8, 9) ['N', 'W']
# (9, 0) ['S', 'W']
# (9, 1) ['N', 'W']
# (9, 2) ['S', 'W']
# (9, 3) ['N', 'S']
# (9, 4) ['N', 'S', 'W']
# (9, 5) ['N', 'S']
# (9, 6) ['N', 'S']
# (9, 7) ['N', 'S', 'W']
# (9, 8) ['N', 'S']
# (0, 0) ['E', 'S']
# (0, 1) ['N', 'S']
# (0, 2) ['N', 'S']
# (0, 3) ['N', 'E', 'S']
# (0, 4) ['N', 'E']
# (0, 5) ['S']
# (0, 6) ['N', 'E', 'S']
# (0, 7) ['N', 'S']
# (0, 8) ['N', 'E', 'S']
# (0, 9) ['N', 'E']
# (1, 0) ['E', 'W']
# (1, 1) ['E', 'S']
# (1, 2) ['N', 'S']
# (1, 3) ['N', 'W']
# (1, 4) ['S', 'W']
# (1, 5) ['N', 'E']
# (1, 6) ['W']
# (1, 7) ['E', 'S']
# (1, 8) ['N', 'W']
# (1, 9) ['E', 'W']
# (2, 0) ['W']
# (2, 1) ['E', 'W']
# (2, 2) ['E', 'S']
# (2, 3) ['N', 'E']
# (2, 4) ['E', 'S']
# (2, 5) ['N', 'W']
# (2, 6) ['E', 'S']
# (2, 7) ['N', 'W']
# (2, 8) ['E', 'S']
# (2, 9) ['N', 'W']
# (3, 0) ['E', 'S']
# (3, 1) ['N', 'W']
# (3, 2) ['W']
# (3, 3) ['S', 'W']
# (3, 4) ['N', 'S', 'W']
# (3, 5) ['N', 'E']
# (3, 6) ['E', 'S', 'W']
# (3, 7) ['N', 'E']
# (3, 8) ['S', 'W']
# (3, 9) ['N', 'E']
# (4, 0) ['E', 'W']
# (4, 1) ['E', 'S']
# (4, 2) ['N', 'S']
# (4, 3) ['N', 'S']
# (4, 4) ['N', 'E']
# (4, 5) ['E', 'W']
# (4, 6) ['E', 'W']
# (4, 7) ['E', 'W']
# (4, 8) ['E', 'S']
# (4, 9) ['N', 'W']
# (5, 0) ['E', 'S', 'W']
# (5, 1) ['N', 'W']
# (5, 2) ['E', 'S']
# (5, 3) ['N', 'S']
# (5, 4) ['N', 'W']
# (5, 5) ['E', 'W']
# (5, 6) ['W']
# (5, 7) ['E', 'W']
# (5, 8) ['S', 'W']
# (5, 9) ['N', 'E']
# (6, 0) ['S', 'W']
# (6, 1) ['N', 'E']
# (6, 2) ['S', 'W']
# (6, 3) ['N', 'S']
# (6, 4) ['N', 'E']
# (6, 5) ['S', 'W']
# (6, 6) ['N', 'S']
# (6, 7) ['N', 'S', 'W']
# (6, 8) ['N']
# (6, 9) ['E', 'W']
# (7, 0) ['E']
# (7, 1) ['S', 'W']
# (7, 2) ['N', 'S']
# (7, 3) ['N', 'E']
# (7, 4) ['S', 'W']
# (7, 5) ['N', 'S']
# (7, 6) ['N', 'S']
# (7, 7) ['N', 'S']
# (7, 8) ['N', 'E']
# (7, 9) ['E', 'W']
# (8, 0) ['E', 'W']
# (8, 1) ['E', 'S']
# (8, 2) ['N', 'E']
# (8, 3) ['S', 'W']
# (8, 4) ['N', 'E']
# (8, 5) ['S']
# (8, 6) ['N', 'S']
# (8, 7) ['N', 'E']
# (8, 8) ['S', 'W']
# (8, 9) ['N', 'W']
# (9, 0) ['S', 'W']
# (9, 1) ['N', 'W']
# (9, 2) ['S', 'W']
# (9, 3) ['N', 'S']
# (9, 4) ['N', 'S', 'W']
# (9, 5) ['N', 'S']
# (9, 6) ['N', 'S']
# (9, 7) ['N', 'S', 'W']
# (9, 8) ['N', 'S']
# (0, 0) ['E', 'S']
# (0, 1) ['N', 'S']
# (0, 2) ['N', 'S']
# (0, 3) ['N', 'E', 'S']
# (0, 4) ['N', 'E']
# (0, 5) ['S']
# (0, 6) ['N', 'E', 'S']
# (0, 7) ['N', 'S']
# (0, 8) ['N', 'E', 'S']
# (0, 9) ['N', 'E']
# (1, 0) ['E', 'W']
# (1, 1) ['E', 'S']
# (1, 2) ['N', 'S']
# (1, 3) ['N', 'W']
# (1, 4) ['S', 'W']
# (1, 5) ['N', 'E']
# (1, 6) ['W']
# (1, 7) ['E', 'S']
# (1, 8) ['N', 'W']
# (1, 9) ['E', 'W']
# (2, 0) ['W']
# (2, 1) ['E', 'W']
# (2, 2) ['E', 'S']
# (2, 3) ['N', 'E']
# (2, 4) ['E', 'S']
# (2, 5) ['N', 'W']
# (2, 6) ['E', 'S']
# (2, 7) ['N', 'W']
# (2, 8) ['E', 'S']
# (2, 9) ['N', 'W']
# (3, 0) ['E', 'S']
# (3, 1) ['N', 'W']
# (3, 2) ['W']
# (3, 3) ['S', 'W']
# (3, 4) ['N', 'S', 'W']
# (3, 5) ['N', 'E']
# (3, 6) ['E', 'S', 'W']
# (3, 7) ['N', 'E']
# (3, 8) ['S', 'W']
# (3, 9) ['N', 'E']
# (4, 0) ['E', 'W']
# (4, 1) ['E', 'S']
# (4, 2) ['N', 'S']
# (4, 3) ['N', 'S']
# (4, 4) ['N', 'E']
# (4, 5) ['E', 'W']
# (4, 6) ['E', 'W']
# (4, 7) ['E', 'W']
# (4, 8) ['E', 'S']
# (4, 9) ['N', 'W']
# (5, 0) ['E', 'S', 'W']
# (5, 1) ['N', 'W']
# (5, 2) ['E', 'S']
# (5, 3) ['N', 'S']
# (5, 4) ['N', 'W']
# (5, 5) ['E', 'W']
# (5, 6) ['W']
# (5, 7) ['E', 'W']
# (5, 8) ['S', 'W']
# (5, 9) ['N', 'E']
# (6, 0) ['S', 'W']
# (6, 1) ['N', 'E']
# (6, 2) ['S', 'W']
# (6, 3) ['N', 'S']
# (6, 4) ['N', 'E']
# (6, 5) ['S', 'W']
# (6, 6) ['N', 'S']
# (6, 7) ['N', 'S', 'W']
# (6, 8) ['N']
# (6, 9) ['E', 'W']
# (7, 0)
# /home/yaroslav/.local/lib/python3.9/site-packages/gym/logger.py:30: UserWarning: WARN: Trying to monitor an environment which has no 'spec' set. This usually means you did not create it via 'gym.make', and is recommended only for advanced users.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
#  ['E']
# (7, 1) ['S', 'W']
# (7, 2) ['N', 'S']
# (7, 3) ['N', 'E']
# (7, 4) ['S', 'W']
# (7, 5) ['N', 'S']
# (7, 6) ['N', 'S']
# (7, 7) ['N', 'S']
# (7, 8) ['N', 'E']
# (7, 9) ['E', 'W']
# (8, 0) ['E', 'W']
# (8, 1) ['E', 'S']
# (8, 2) ['N', 'E']
# (8, 3) ['S', 'W']
# (8, 4) ['N', 'E']
# (8, 5) ['S']
# (8, 6) ['N', 'S']
# (8, 7) ['N', 'E']
# (8, 8) ['S', 'W']
# (8, 9) ['N', 'W']
# (9, 0) ['S', 'W']
# (9, 1) ['N', 'W']
# (9, 2) ['S', 'W']
# (9, 3) ['N', 'S']
# (9, 4) ['N', 'S', 'W']
# (9, 5) ['N', 'S']
# (9, 6) ['N', 'S']
# (9, 7) ['N', 'S', 'W']
# (9, 8) ['N', 'S']
# (0, 0) ['E', 'S']
# (0, 1) ['N', 'S']
# (0, 2) ['N', 'S']
# (0, 3) ['N', 'E', 'S']
# (0, 4) ['N', 'E']
# (0, 5) ['S']
# (0, 6) ['N', 'E', 'S']
# (0, 7) ['N', 'S']
# (0, 8) ['N', 'E', 'S']
# (0, 9) ['N', 'E']
# (1, 0) ['E', 'W']
# (1, 1) ['E', 'S']
# (1, 2) ['N', 'S']
# (1, 3) ['N', 'W']
# (1, 4) ['S', 'W']
# (1, 5) ['N', 'E']
# (1, 6) ['W']
# (1, 7) ['E', 'S']
# (1, 8) ['N', 'W']
# (1, 9) ['E', 'W']
# (2, 0) ['W']
# (2, 1) ['E', 'W']
# (2, 2) ['E', 'S']
# (2, 3) ['N', 'E']
# (2, 4) ['E', 'S']
# (2, 5) ['N', 'W']
# (2, 6) ['E', 'S']
# (2, 7) ['N', 'W']
# (2, 8) ['E', 'S']
# (2, 9) ['N', 'W']
# (3, 0) ['E', 'S']
# (3, 1) ['N', 'W']
# (3, 2) ['W']
# (3, 3) ['S', 'W']
# (3, 4) ['N', 'S', 'W']
# (3, 5) ['N', 'E']
# (3, 6) ['E', 'S', 'W']
# (3, 7) ['N', 'E']
# (3, 8) ['S', 'W']
# (3, 9) ['N', 'E']
# (4, 0) ['E', 'W']
# (4, 1) ['E', 'S']
# (4, 2) ['N', 'S']
# (4, 3) ['N', 'S']
# (4, 4) ['N', 'E']
# (4, 5) ['E', 'W']
# (4, 6) ['E', 'W']
# (4, 7) ['E', 'W']
# (4, 8) ['E', 'S']
# (4, 9) ['N', 'W']
# (5, 0) ['E', 'S', 'W']
# (5, 1) ['N', 'W']
# (5, 2) ['E', 'S']
# (5, 3) ['N', 'S']
# (5, 4) ['N', 'W']
# (5, 5) ['E', 'W']
# (5, 6) ['W']
# (5, 7) ['E', 'W']
# (5, 8) ['S', 'W']
# (5, 9) ['N', 'E']
# (6, 0) ['S', 'W']
# (6, 1) ['N', 'E']
# (6, 2) ['S', 'W']
# (6, 3) ['N', 'S']
# (6, 4) ['N', 'E']
# (6, 5) ['S', 'W']
# (6, 6) ['N', 'S']
# (6, 7) ['N', 'S', 'W']
# (6, 8) ['N']
# (6, 9) ['E', 'W']
# (7, 0) ['E']
# (7, 1) ['S', 'W']
# (7, 2) ['N', 'S']
# (7, 3) ['N', 'E']
# (7, 4) ['S', 'W']
# (7, 5) ['N', 'S']
# (7, 6) ['N', 'S']
# (7, 7) ['N', 'S']
# (7, 8) ['N', 'E']
# (7, 9) ['E', 'W']
# (8, 0) ['E', 'W']
# (8, 1) ['E', 'S']
# (8, 2) ['N', 'E']
# (8, 3) ['S', 'W']
# (8, 4) ['N', 'E']
# (8, 5) ['S']
# (8, 6) ['N', 'S']
# (8, 7) ['N', 'E']
# (8, 8) ['S', 'W']
# (8, 9) ['N', 'W']
# (9, 0) ['S', 'W']
# (9, 1) ['N', 'W']
# (9, 2) ['S', 'W']
# (9, 3) ['N', 'S']
# (9, 4) ['N', 'S', 'W']
# (9, 5) ['N', 'S']
# (9, 6) ['N', 'S']
# (9, 7) ['N', 'S', 'W']
# (9, 8) ['N', 'S']
# (0, 0) ['E', 'S']
# (0, 1) ['N', 'S']
# (0, 2) ['N', 'S']
# (0, 3) ['N', 'E', 'S']
# (0, 4) ['N', 'E']
# (0, 5) ['S']
# (0, 6) ['N', 'E', 'S']
# (0, 7) ['N', 'S']
# (0, 8) ['N', 'E', 'S']
# (0, 9) ['N', 'E']
# (1, 0) ['E', 'W']
# (1, 1) ['E', 'S']
# (1, 2) ['N', 'S']
# (1, 3) ['N', 'W']
# (1, 4) ['S', 'W']
# (1, 5) ['N', 'E']
# (1, 6) ['W']
# (1, 7) ['E', 'S']
# (1, 8) ['N', 'W']
# (1, 9) ['E', 'W']
# (2, 0) ['W']
# (2, 1) ['E', 'W']
# (2, 2) ['E', 'S']
# (2, 3) ['N', 'E']
# (2, 4) ['E', 'S']
# (2, 5) ['N', 'W']
# (2, 6) ['E', 'S']
# (2, 7) ['N', 'W']
# (2, 8) ['E', 'S']
# (2, 9) ['N', 'W']
# (3, 0) ['E', 'S']
# (3, 1) ['N', 'W']
# (3, 2) ['W']
# (3, 3) ['S', 'W']
# (3, 4) ['N', 'S', 'W']
# (3, 5) ['N', 'E']
# (3, 6) ['E', 'S', 'W']
# (3, 7) ['N', 'E']
# (3, 8) ['S', 'W']
# (3, 9) ['N', 'E']
# (4, 0) ['E', 'W']
# (4, 1) ['E', 'S']
# (4, 2) ['N', 'S']
# (4, 3) ['N', 'S']
# (4, 4) ['N', 'E']
# (4, 5) ['E', 'W']
# (4, 6) ['E', 'W']
# (4, 7) ['E', 'W']
# (4, 8) ['E', 'S']
# (4, 9) ['N', 'W']
# (5, 0) ['E', 'S', 'W']
# (5, 1) ['N', 'W']
# (5, 2) ['E', 'S']
# (5, 3) ['N', 'S']
# (5, 4) ['N', 'W']
# (5, 5) ['E', 'W']
# (5, 6) ['W']
# (5, 7) ['E', 'W']
# (5, 8) ['S', 'W']
# (5, 9) ['N', 'E']
# (6, 0) ['S', 'W']
# (6, 1) ['N', 'E']
# (6, 2) ['S', 'W']
# (6, 3) ['N', 'S']
# (6, 4) ['N', 'E']
# (6, 5) ['S', 'W']
# (6, 6) ['N', 'S']
# (6, 7) ['N', 'S', 'W']
# (6, 8) ['N']
# (6, 9) ['E', 'W']
# (7, 0) ['E']
# (7, 1) ['S', 'W']
# (7, 2) ['N', 'S']
# (7, 3) ['N', 'E']
# (7, 4) ['S', 'W']
# (7, 5) ['N', 'S']
# (7, 6) ['N', 'S']
# (7, 7) ['N', 'S']
# (7, 8) ['N', 'E']
# (7, 9) ['E', 'W']
# (8, 0) ['E', 'W']
# (8, 1) ['E', 'S']
# (8, 2) ['N', 'E']
# (8, 3) ['S', 'W']
# (8, 4) ['N', 'E']
# (8, 5) ['S']
# (8, 6) ['N', 'S']
# (8, 7) ['N', 'E']
# (8, 8) ['S', 'W']
# (8, 9) ['N', 'W']
# (9, 0) ['S', 'W']
# (9, 1) ['N', 'W']
# (9, 2) ['S', 'W']
# (9, 3) ['N', 'S']
# (9, 4) ['N', 'S', 'W']
# (9, 5) ['N', 'S']
# (9, 6) ['N', 'S']
# (9, 7) ['N', 'S', 'W']
# (9, 8) ['N', 'S']
# (0, 0) ['E', 'S']
# (0, 1) ['N', 'S']
# (0, 2) ['N', 'S']
# (0, 3) ['N', 'E', 'S']
# (0, 4) ['N', 'E']
# (0, 5) ['S']
# (0, 6) ['N', 'E', 'S']
# (0, 7) ['N', 'S']
# (0, 8) ['N', 'E', 'S']
# (0, 9) ['N', 'E']
# (1, 0) ['E', 'W']
# (1, 1) ['E', 'S']
# (1, 2) ['N', 'S']
# (1, 3) ['N', 'W']
# (1, 4) ['S', 'W']
# (1, 5) ['N', 'E']
# (1, 6) ['W']
# (1, 7) ['E', 'S']
# (1, 8) ['N', 'W']
# (1, 9) ['E', 'W']
# (2, 0) ['W']
# (2, 1) ['E', 'W']
# (2, 2) ['E', 'S']
# (2, 3) ['N', 'E']
# (2, 4) ['E', 'S']
# (2, 5) ['N', 'W']
# (2, 6) ['E', 'S']
# (2, 7) ['N', 'W']
# (2, 8) ['E', 'S']
# (2, 9) ['N', 'W']
# (3, 0) ['E', 'S']
# (3, 1) ['N', 'W']
# (3, 2) ['W']
# (3, 3) ['S', 'W']
# (3, 4) ['N', 'S', 'W']
# (3, 5) ['N', 'E']
# (3, 6) ['E', 'S', 'W']
# (3, 7) ['N', 'E']
# (3, 8) ['S', 'W']
# (3, 9) ['N', 'E']
# (4, 0) ['E', 'W']
# (4, 1) ['E', 'S']
# (4, 2) ['N', 'S']
# (4, 3) ['N', 'S']
# (4, 4) ['N', 'E']
# (4, 5) ['E', 'W']
# (4, 6) ['E', 'W']
# (4, 7) ['E', 'W']
# (4, 8) ['E', 'S']
# (4, 9) ['N', 'W']
# (5, 0) ['E', 'S', 'W']
# (5, 1) ['N', 'W']
# (5, 2) ['E', 'S']
# (5, 3) ['N', 'S']
# (5, 4) ['N', 'W']
# (5, 5) ['E', 'W']
# (5, 6) ['W']
# (5, 7) ['E', 'W']
# (5, 8) ['S', 'W']
# (5, 9) ['N', 'E']
# (6, 0) ['S', 'W']
# (6, 1) ['N', 'E']
# (6, 2) ['S', 'W']
# (6, 3) ['N', 'S']
# (6, 4) ['N', 'E']
# (6, 5) ['S', 'W']
# (6, 6) ['N', 'S']
# (6, 7) ['N', 'S', 'W']
# (6, 8) ['N']
# (6, 9) ['E', 'W']
# (7, 0) ['E']
# (7, 1) ['S', 'W']
# (7, 2) ['N', 'S']
# (7, 3) ['N', 'E']
# (7, 4) ['S', 'W']
# (7, 5) ['N', 'S']
# (7, 6) ['N', 'S']
# (7, 7) ['N', 'S']
# (7, 8) ['N', 'E']
# (7, 9) ['E', 'W']
# (8, 0) ['E', 'W']
# (8, 1) ['E', 'S']
# (8, 2) ['N', 'E']
# (8, 3) ['S', 'W']
# (8, 4) ['N', 'E']
# (8, 5) ['S']
# (8, 6) ['N', 'S']
# (8, 7) ['N', 'E']
# (8, 8) ['S', 'W']
# (8, 9) ['N', 'W']
# (9, 0) ['S', 'W']
# (9, 1) ['N', 'W']
# (9, 2) ['S', 'W']
# (9, 3) ['N', 'S']
# (9, 4) ['N', 'S', 'W']
# (9, 5) ['N', 'S']
# (9, 6) ['N', 'S']
# (9, 7) ['N', 'S', 'W']
# (9, 8) ['N', 'S']
# (0, 0) ['E', 'S']
# (0, 1) ['N', 'S']
# (0, 2) ['N', 'S']
# (0, 3) ['N', 'E', 'S']
# (0, 4) ['N', 'E']
# (0, 5) ['S']
# (0, 6) ['N', 'E', 'S']
# (0, 7) ['N', 'S']
# (0, 8) ['N', 'E', 'S']
# (0, 9) ['N', 'E']
# (1, 0) ['E', 'W']
# (1, 1) ['E', 'S']
# (1, 2) ['N', 'S']
# (1, 3) ['N', 'W']
# (1, 4) ['S', 'W']
# (1, 5) ['N', 'E']
# (1, 6) ['W']
# (1, 7) ['E', 'S']
# (1, 8) ['N', 'W']
# (1, 9) ['E', 'W']
# (2, 0) ['W']
# (2, 1) ['E', 'W']
# (2, 2) ['E', 'S']
# (2, 3) ['N', 'E']
# (2, 4) ['E', 'S']
# (2, 5) ['N', 'W']
# (2, 6) ['E', 'S']
# (2, 7) ['N', 'W']
# (2, 8) ['E', 'S']
# (2, 9) ['N', 'W']
# (3, 0) ['E', 'S']
# (3, 1) ['N', 'W']
# (3, 2) ['W']
# (3, 3) ['S', 'W']
# (3, 4) ['N', 'S', 'W']
# (3, 5) ['N', 'E']
# (3, 6) ['E', 'S', 'W']
# (3, 7) ['N', 'E']
# (3, 8) ['S', 'W']
# (3, 9) ['N', 'E']
# (4, 0) ['E', 'W']
# (4, 1) ['E', 'S']
# (4, 2) ['N', 'S']
# (4, 3) ['N', 'S']
# (4, 4) ['N', 'E']
# (4, 5) ['E', 'W']
# (4, 6) ['E', 'W']
# (4, 7) ['E', 'W']
# (4, 8) ['E', 'S']
# (4, 9) ['N', 'W']
# (5, 0) ['E', 'S', 'W']
# (5, 1) ['N', 'W']
# (5, 2) ['E', 'S']
# (5, 3) ['N', 'S']
# (5, 4) ['N', 'W']
# (5, 5) ['E', 'W']
# (5, 6) ['W']
# (5, 7) ['E', 'W']
# (5, 8) ['S', 'W']
# (5, 9) ['N', 'E']
# (6, 0) ['S', 'W']
# (6, 1) ['N', 'E']
# (6, 2) ['S', 'W']
# (6, 3) ['N', 'S']
# (6, 4) ['N', 'E']
# (6, 5) ['S', 'W']
# (6, 6) ['N', 'S']
# (6, 7) ['N', 'S', 'W']
# (6, 8) ['N']
# (6, 9) ['E', 'W']
# (7, 0) ['E']
# (7, 1) ['S', 'W']
# (7, 2) ['N', 'S']
# (7, 3) ['N', 'E']
# (7, 4) ['S', 'W']
# (7, 5) ['N', 'S']
# (7, 6) ['N', 'S']
# (7, 7) ['N', 'S']
# (7, 8) ['N', 'E']
# (7, 9) ['E', 'W']
# (8, 0) ['E', 'W']
# (8, 1) ['E', 'S']
# (8, 2) ['N', 'E']
# (8, 3) ['S', 'W']
# (8, 4) ['N', 'E']
# (8, 5) ['S']
# (8, 6) ['N', 'S']
# (8, 7) ['N', 'E']
# (8, 8) ['S', 'W']
# (8, 9) ['N', 'W']
# (9, 0) ['S', 'W']
# (9, 1) ['N', 'W']
# (9, 2) ['S', 'W']
# (9, 3) ['N', 'S']
# (9, 4) ['N', 'S', 'W']
# (9, 5) ['N', 'S']
# (9, 6) ['N', 'S']
# (9, 7) ['N', 'S', 'W']
# (9, 8) ['N', 'S']
# (0, 0) ['E', 'S']
# (0, 1) ['N', 'S']
# (0, 2) ['N', 'S']
# (0, 3) ['N', 'E', 'S']
# (0, 4) ['N', 'E']
# (0, 5) ['S']
# (0, 6) ['N', 'E', 'S']
# (0, 7) ['N', 'S']
# (0, 8) ['N', 'E', 'S']
# (0, 9) ['N', 'E']
# (1, 0) ['E', 'W']
# (1, 1) ['E', 'S']
# (1, 2) ['N', 'S']
# (1, 3) ['N', 'W']
# (1, 4) ['S', 'W']
# (1, 5) ['N', 'E']
# (1, 6) ['W']
# (1, 7) ['E', 'S']
# (1, 8) ['N', 'W']
# (1, 9) ['E', 'W']
# (2, 0) ['W']
# (2, 1) ['E', 'W']
# (2, 2) ['E', 'S']
# (2, 3) ['N', 'E']
# (2, 4) ['E', 'S']
# (2, 5) ['N', 'W']
# (2, 6) ['E', 'S']
# (2, 7) ['N', 'W']
# (2, 8) ['E', 'S']
# (2, 9) ['N', 'W']
# (3, 0) ['E', 'S']
# (3, 1) ['N', 'W']
# (3, 2) ['W']
# (3, 3) ['S', 'W']
# (3, 4) ['N', 'S', 'W']
# (3, 5) ['N', 'E']
# (3, 6) ['E', 'S', 'W']
# (3, 7) ['N', 'E']
# (3, 8) ['S', 'W']
# (3, 9) ['N', 'E']
# (4, 0) ['E', 'W']
# (4, 1) ['E', 'S']
# (4, 2) ['N', 'S']
# (4, 3) ['N', 'S']
# (4, 4) ['N', 'E']
# (4, 5) ['E', 'W']
# (4, 6) ['E', 'W']
# (4, 7) ['E', 'W']
# (4, 8) ['E', 'S']
# (4, 9) ['N', 'W']
# (5, 0) ['E', 'S', 'W']
# (5, 1) ['N', 'W']
# (5, 2) ['E', 'S']
# (5, 3) ['N', 'S']
# (5, 4) ['N', 'W']
# (5, 5) ['E', 'W']
# (5, 6) ['W']
# (5, 7) ['E', 'W']
# (5, 8) ['S', 'W']
# (5, 9) ['N', 'E']
# (6, 0) ['S', 'W']
# (6, 1) ['N', 'E']
# (6, 2) ['S', 'W']
# (6, 3) ['N', 'S']
# (6, 4) ['N', 'E']
# (6, 5) ['S', 'W']
# (6, 6) ['N', 'S']
# (6, 7) ['N', 'S', 'W']
# (6, 8) ['N']
# (6, 9) ['E', 'W']
# (7, 0) ['E']
# (7, 1) ['S', 'W']
# (7, 2) ['N', 'S']
# (7, 3) ['N', 'E']
# (7, 4) ['S', 'W']
# (7, 5) ['N', 'S']
# (7, 6) ['N', 'S']
# (7, 7) ['N', 'S']
# (7, 8) ['N', 'E']
# (7, 9) ['E', 'W']
# (8, 0) ['E', 'W']
# (8, 1) ['E', 'S']
# (8, 2) ['N', 'E']
# (8, 3) ['S', 'W']
# (8, 4) ['N', 'E']
# (8, 5) ['S']
# (8, 6) ['N', 'S']
# (8, 7) ['N', 'E']
# (8, 8) ['S', 'W']
# (8, 9) ['N', 'W']
# (9, 0) ['S', 'W']
# (9, 1) ['N', 'W']
# (9, 2) ['S', 'W']
# (9, 3) ['N', 'S']
# (9, 4) ['N', 'S', 'W']
# (9, 5) ['N', 'S']
# (9, 6) ['N', 'S']
# (9, 7) ['N', 'S', 'W']
# (9, 8) ['N', 'S']
# (0, 0) ['E', 'S']
# (0, 1) ['N', 'S']
# (0, 2) ['N', 'S']
# (0, 3) ['N', 'E', 'S']
# (0, 4) ['N', 'E']
# (0, 5) ['S']
# (0, 6) ['N', 'E', 'S']
# (0, 7) ['N', 'S']
# (0, 8) ['N', 'E', 'S']
# (0, 9) ['N', 'E']
# (1, 0) ['E', 'W']
# (1, 1) ['E', 'S']
# (1, 2) ['N', 'S']
# (1, 3) ['N', 'W']
# (1, 4) ['S', 'W']
# (1, 5) ['N', 'E']
# (1, 6) ['W']
# (1, 7) ['E', 'S']
# (1, 8) ['N', 'W']
# (1, 9) ['E', 'W']
# (2, 0) ['W']
# (2, 1) ['E', 'W']
# (2, 2) ['E', 'S']
# (2, 3) ['N', 'E']
# (2, 4) ['E', 'S']
# (2, 5) ['N', 'W']
# (2, 6) ['E', 'S']
# (2, 7) ['N', 'W']
# (2, 8) ['E', 'S']
# (2, 9) ['N', 'W']
# (3, 0) ['E', 'S']
# (3, 1) ['N', 'W']
# (3, 2) ['W']
# (3, 3) ['S', 'W']
# (3, 4) ['N', 'S', 'W']
# (3, 5) ['N', 'E']
# (3, 6) ['E', 'S', 'W']
# (3, 7) ['N', 'E']
# (3, 8) ['S', 'W']
# (3, 9) ['N', 'E']
# (4, 0) ['E', 'W']
# (4, 1) ['E', 'S']
# (4, 2) ['N', 'S']
# (4, 3) ['N', 'S']
# (4, 4) ['N', 'E']
# (4, 5) ['E', 'W']
# (4, 6) ['E', 'W']
# (4, 7) ['E', 'W']
# (4, 8) ['E', 'S']
# (4, 9) ['N', 'W']
# (5, 0) ['E', 'S', 'W']
# (5, 1) ['N', 'W']
# (5, 2) ['E', 'S']
# (5, 3) ['N', 'S']
# (5, 4) ['N', 'W']
# (5, 5) ['E', 'W']
# (5, 6) ['W']
# (5, 7) ['E', 'W']
# (5, 8) ['S', 'W']
# (5, 9) ['N', 'E']
# (6, 0) ['S', 'W']
# (6, 1) ['N', 'E']
# (6, 2) ['S', 'W']
# (6, 3) ['N', 'S']
# (6, 4) ['N', 'E']
# (6, 5) ['S', 'W']
# (6, 6) ['N', 'S']
# (6, 7) ['N', 'S', 'W']
# (6, 8) ['N']
# (6, 9) ['E', 'W']
# (7, 0) ['E']
# (7, 1) ['S', 'W']
# (7, 2) ['N', 'S']
# (7, 3) ['N', 'E']
# (7, 4) ['S', 'W']
# (7, 5) ['N', 'S']
# (7, 6) ['N', 'S']
# (7, 7) ['N', 'S']
# (7, 8) ['N', 'E']
# (7, 9) ['E', 'W']
# (8, 0) ['E', 'W']
# (8, 1) ['E', 'S']
# (8, 2) ['N', 'E']
# (8, 3) ['S', 'W']
# (8, 4) ['N', 'E']
# (8, 5) ['S']
# (8, 6) ['N', 'S']
# (8, 7) ['N', 'E']
# (8, 8) ['S', 'W']
# (8, 9) ['N', 'W']
# (9, 0) ['S', 'W']
# (9, 1) ['N', 'W']
# (9, 2) ['S', 'W']
# (9, 3) ['N', 'S']
# (9, 4) ['N', 'S', 'W']
# (9, 5) ['N', 'S']
# (9, 6) ['N', 'S']
# (9, 7) ['N', 'S', 'W']
# (9, 8) ['N', 'S']
# (0, 0) ['E', 'S']
# (0, 1) ['N', 'S']
# (0, 2) ['N', 'S']
# (0, 3) ['N', 'E', 'S']
# (0, 4) ['N', 'E']
# (0, 5) ['S']
# (0, 6) ['N', 'E', 'S']
# (0, 7) ['N', 'S']
# (0, 8) ['N', 'E', 'S']
# (0, 9) ['N', 'E']
# (1, 0) ['E', 'W']
# (1, 1) ['E', 'S']
# (1, 2) ['N', 'S']
# (1, 3) ['N', 'W']
# (1, 4) ['S', 'W']
# (1, 5) ['N', 'E']
# (1, 6) ['W']
# (1, 7) ['E', 'S']
# (1, 8) ['N', 'W']
# (1, 9) ['E', 'W']
# (2, 0) ['W']
# (2, 1) ['E', 'W']
# (2, 2) ['E', 'S']
# (2, 3) ['N', 'E']
# (2, 4) ['E', 'S']
# (2, 5) ['N', 'W']
# (2, 6) ['E', 'S']
# (2, 7) ['N', 'W']
# (2, 8) ['E', 'S']
# (2, 9) ['N', 'W']
# (3, 0) ['E', 'S']
# (3, 1) ['N', 'W']
# (3, 2) ['W']
# (3, 3) ['S', 'W']
# (3, 4) ['N', 'S', 'W']
# (3, 5) ['N', 'E']
# (3, 6) ['E', 'S', 'W']
# (3, 7) ['N', 'E']
# (3, 8) ['S', 'W']
# (3, 9) ['N', 'E']
# (4, 0) ['E', 'W']
# (4, 1) ['E', 'S']
# (4, 2) ['N', 'S']
# (4, 3) ['N', 'S']
# (4, 4) ['N', 'E']
# (4, 5) ['E', 'W']
# (4, 6) ['E', 'W']
# (4, 7) ['E', 'W']
# (4, 8) ['E', 'S']
# (4, 9) ['N', 'W']
# (5, 0) ['E', 'S', 'W']
# (5, 1) ['N', 'W']
# (5, 2) ['E', 'S']
# (5, 3) ['N', 'S']
# (5, 4) ['N', 'W']
# (5, 5) ['E', 'W']
# (5, 6) ['W']
# (5, 7) ['E', 'W']
# (5, 8) ['S', 'W']
# (5, 9) ['N', 'E']
# (6, 0) ['S', 'W']
# (6, 1) ['N', 'E']
# (6, 2) ['S', 'W']
# (6, 3) ['N', 'S']
# (6, 4) ['N', 'E']
# (6, 5) ['S', 'W']
# (6, 6) ['N', 'S']
# (6, 7) ['N', 'S', 'W']
# (6, 8) ['N']
# (6, 9) ['E', 'W']
# (7, 0) ['E']
# (7, 1) ['S', 'W']
# (7, 2) ['N', 'S']
# (7, 3) ['N', 'E']
# (7, 4) ['S', 'W']
# (7, 5) ['N', 'S']
# (7, 6) ['N', 'S']
# (7, 7) ['N', 'S']
# (7, 8) ['N', 'E']
# (7, 9) ['E', 'W']
# (8, 0) ['E', 'W']
# (8, 1) ['E', 'S']
# (8, 2) ['N', 'E']
# (8, 3) ['S', 'W']
# (8, 4) ['N', 'E']
# (8, 5) ['S']
# (8, 6) ['N', 'S']
# (8, 7) ['N', 'E']
# (8, 8) ['S', 'W']
# (8, 9) ['N', 'W']
# (9, 0) ['S', 'W']
# (9, 1) ['N', 'W']
# (9, 2) ['S', 'W']
# (9, 3) ['N', 'S']
# (9, 4) ['N', 'S', 'W']
# (9, 5) ['N', 'S']
# (9, 6) ['N', 'S']
# (9, 7) ['N', 'S', 'W']
# (9, 8) ['N', 'S']
# (0, 0) ['E', 'S']
# (0, 1) ['N', 'S']
# (0, 2) ['N', 'S']
# (0, 3) ['N', 'E', 'S']
# (0, 4) ['N', 'E']
# (0, 5) ['S']
# (0, 6) ['N', 'E', 'S']
# (0, 7) ['N', 'S']
# (0, 8) ['N', 'E', 'S']
# (0, 9) ['N', 'E']
# (1, 0) ['E', 'W']
# (1, 1) ['E', 'S']
# (1, 2) ['N', 'S']
# (1, 3) ['N', 'W']
# (1, 4) ['S', 'W']
# (1, 5) ['N', 'E']
# (1, 6) ['W']
# (1, 7) ['E', 'S']
# (1, 8) ['N', 'W']
# (1, 9) ['E', 'W']
# (2, 0) ['W']
# (2, 1) ['E', 'W']
# (2, 2) ['E', 'S']
# (2, 3) ['N', 'E']
# (2, 4) ['E', 'S']
# (2, 5) ['N', 'W']
# (2, 6) ['E', 'S']
# (2, 7) ['N', 'W']
# (2, 8) ['E', 'S']
# (2, 9) ['N', 'W']
# (3, 0) ['E', 'S']
# (3, 1) ['N', 'W']
# (3, 2) ['W']
# (3, 3) ['S', 'W']
# (3, 4) ['N', 'S', 'W']
# (3, 5) ['N', 'E']
# (3, 6) ['E', 'S', 'W']
# (3, 7) ['N', 'E']
# (3, 8) ['S', 'W']
# (3, 9) ['N', 'E']
# (4, 0) ['E', 'W']
# (4, 1) ['E', 'S']
# (4, 2) ['N', 'S']
# (4, 3) ['N', 'S']
# (4, 4) ['N', 'E']
# (4, 5) ['E', 'W']
# (4, 6) ['E', 'W']
# (4, 7) ['E', 'W']
# (4, 8) ['E', 'S']
# (4, 9) ['N', 'W']
# (5, 0) ['E', 'S', 'W']
# (5, 1) ['N', 'W']
# (5, 2) ['E', 'S']
# (5, 3) ['N', 'S']
# (5, 4) ['N', 'W']
# (5, 5) ['E', 'W']
# (5, 6) ['W']
# (5, 7) ['E', 'W']
# (5, 8) ['S', 'W']
# (5, 9) ['N', 'E']
# (6, 0) ['S', 'W']
# (6, 1) ['N', 'E']
# (6, 2) ['S', 'W']
# (6, 3) ['N', 'S']
# (6, 4) ['N', 'E']
# (6, 5) ['S', 'W']
# (6, 6) ['N', 'S']
# (6, 7) ['N', 'S', 'W']
# (6, 8) ['N']
# (6, 9) ['E', 'W']
# (7, 0) ['E']
# (7, 1) ['S', 'W']
# (7, 2) ['N', 'S']
# (7, 3) ['N', 'E']
# (7, 4) ['S', 'W']
# (7, 5) ['N', 'S']
# (7, 6) ['N', 'S']
# (7, 7) ['N', 'S']
# (7, 8) ['N', 'E']
# (7, 9) ['E', 'W']
# (8, 0) ['E', 'W']
# (8, 1) ['E', 'S']
# (8, 2) ['N', 'E']
# (8, 3) ['S', 'W']
# (8, 4) ['N', 'E']
# (8, 5) ['S']
# (8, 6) ['N', 'S']
# (8, 7) ['N', 'E']
# (8, 8) ['S', 'W']
# (8, 9) ['N', 'W']
# (9, 0) ['S', 'W']
# (9, 1) ['N', 'W']
# (9, 2) ['S', 'W']
# (9, 3) ['N', 'S']
# (9, 4) ['N', 'S', 'W']
# (9, 5) ['N', 'S']
# (9, 6) ['N', 'S']
# (9, 7) ['N', 'S', 'W']
# (9, 8) ['N', 'S']
# (0, 0) ['E', 'S']
# (0, 1) ['N', 'S']
# (0, 2) ['N', 'S']
# (0, 3) ['N', 'E', 'S']
# (0, 4) ['N', 'E']
# (0, 5) ['S']
# (0, 6) ['N', 'E', 'S']
# (0, 7) ['N', 'S']
# (0, 8) ['N', 'E', 'S']
# (0, 9) ['N', 'E']
# (1, 0) ['E', 'W']
# (1, 1) ['E', 'S']
# (1, 2) ['N', 'S']
# (1, 3) ['N', 'W']
# (1, 4) ['S', 'W']
# (1, 5) ['N', 'E']
# (1, 6) ['W']
# (1, 7) ['E', 'S']
# (1, 8) ['N', 'W']
# (1, 9) ['E', 'W']
# (2, 0) ['W']
# (2, 1) ['E', 'W']
# (2, 2) ['E', 'S']
# (2, 3) ['N', 'E']
# (2, 4) ['E', 'S']
# (2, 5) ['N', 'W']
# (2, 6) ['E', 'S']
# (2, 7) ['N', 'W']
# (2, 8) ['E', 'S']
# (2, 9) ['N', 'W']
# (3, 0) ['E', 'S']
# (3, 1) ['N', 'W']
# (3, 2) ['W']
# (3, 3) ['S', 'W']
# (3, 4) ['N', 'S', 'W']
# (3, 5) ['N', 'E']
# (3, 6) ['E', 'S', 'W']
# (3, 7) ['N', 'E']
# (3, 8) ['S', 'W']
# (3, 9) ['N', 'E']
# (4, 0) ['E', 'W']
# (4, 1) ['E', 'S']
# (4, 2) ['N', 'S']
# (4, 3) ['N', 'S']
# (4, 4) ['N', 'E']
# (4, 5) ['E', 'W']
# (4, 6) ['E', 'W']
# (4, 7) ['E', 'W']
# (4, 8) ['E', 'S']
# (4, 9) ['N', 'W']
# (5, 0) ['E', 'S', 'W']
# (5, 1) ['N', 'W']
# (5, 2) ['E', 'S']
# (5, 3) ['N', 'S']
# (5, 4) ['N', 'W']
# (5, 5) ['E', 'W']
# (5, 6) ['W']
# (5, 7) ['E', 'W']
# (5, 8) ['S', 'W']
# (5, 9) ['N', 'E']
# (6, 0) ['S', 'W']
# (6, 1) ['N', 'E']
# (6, 2) ['S', 'W']
# (6, 3) ['N', 'S']
# (6, 4) ['N', 'E']
# (6, 5) ['S', 'W']
# (6, 6) ['N', 'S']
# (6, 7) ['N', 'S', 'W']
# (6, 8) ['N']
# (6, 9) ['E', 'W']
# (7, 0) ['E']
# (7, 1) ['S', 'W']
# (7, 2) ['N', 'S']
# (7, 3) ['N', 'E']
# (7, 4) ['S', 'W']
# (7, 5) ['N', 'S']
# (7, 6) ['N', 'S']
# (7, 7) ['N', 'S']
# (7, 8) ['N', 'E']
# (7, 9) ['E', 'W']
# (8, 0) ['E', 'W']
# (8, 1) ['E', 'S']
# (8, 2) ['N', 'E']
# (8, 3) ['S', 'W']
# (8, 4) ['N', 'E']
# (8, 5) ['S']
# (8, 6) ['N', 'S']
# (8, 7) ['N', 'E']
# (8, 8) ['S', 'W']
# (8, 9) ['N', 'W']
# (9, 0) ['S', 'W']
# (9, 1) ['N', 'W']
# (9, 2) ['S', 'W']
# (9, 3) ['N', 'S']
# (9, 4) ['N', 'S', 'W']
# (9, 5) ['N', 'S']
# (9, 6) ['N', 'S']
# (9, 7) ['N', 'S', 'W']
# (9, 8) ['N', 'S']
# (0, 0) ['E', 'S']
# (0, 1) ['N', 'S']
# (0, 2) ['N', 'S']
# (0, 3) ['N', 'E', 'S']
# (0, 4) ['N', 'E']
# (0, 5) ['S']
# (0, 6) ['N', 'E', 'S']
# (0, 7) ['N', 'S']
# (0, 8) ['N', 'E', 'S']
# (0, 9) ['N', 'E']
# (1, 0) ['E', 'W']
# (1, 1) ['E', 'S']
# (1, 2) ['N', 'S']
# (1, 3) ['N', 'W']
# (1, 4) ['S', 'W']
# (1, 5) ['N', 'E']
# (1, 6) ['W']
# (1, 7) ['E', 'S']
# (1, 8) ['N', 'W']
# (1, 9) ['E', 'W']
# (2, 0) ['W']
# (2, 1) ['E', 'W']
# (2, 2) ['E', 'S']
# (2, 3) ['N', 'E']
# (2, 4) ['E', 'S']
# (2, 5) ['N', 'W']
# (2, 6) ['E', 'S']
# (2, 7) ['N', 'W']
# (2, 8) ['E', 'S']
# (2, 9) ['N', 'W']
# (3, 0) ['E', 'S']
# (3, 1) ['N', 'W']
# (3, 2) ['W']
# (3, 3) ['S', 'W']
# (3, 4) ['N', 'S', 'W']
# (3, 5) ['N', 'E']
# (3, 6) ['E', 'S', 'W']
# (3, 7) ['N', 'E']
# (3, 8) ['S', 'W']
# (3, 9) ['N', 'E']
# (4, 0) ['E', 'W']
# (4, 1) ['E', 'S']
# (4, 2) ['N', 'S']
# (4, 3) ['N', 'S']
# (4, 4) ['N', 'E']
# (4, 5) ['E', 'W']
# (4, 6) ['E', 'W']
# (4, 7) ['E', 'W']
# (4, 8) ['E', 'S']
# (4, 9) ['N', 'W']
# (5, 0) ['E', 'S', 'W']
# (5, 1) ['N', 'W']
# (5, 2) ['E', 'S']
# (5, 3) ['N', 'S']
# (5, 4) ['N', 'W']
# (5, 5) ['E', 'W']
# (5, 6) ['W']
# (5, 7) ['E', 'W']
# (5, 8) ['S', 'W']
# (5, 9) ['N', 'E']
# (6, 0) ['S', 'W']
# (6, 1) ['N', 'E']
# (6, 2) ['S', 'W']
# (6, 3) ['N', 'S']
# (6, 4) ['N', 'E']
# (6, 5) ['S', 'W']
# (6, 6) ['N', 'S']
# (6, 7) ['N', 'S', 'W']
# (6, 8) ['N']
# (6, 9) ['E', 'W']
# (7, 0) ['E']
# (7, 1) ['S', 'W']
# (7, 2) ['N', 'S']
# (7, 3) ['N', 'E']
# (7, 4) ['S', 'W']
# (7, 5) ['N', 'S']
# (7, 6) ['N', 'S']
# (7, 7) ['N', 'S']
# (7, 8) ['N', 'E']
# (7, 9) ['E', 'W']
# (8, 0) ['E', 'W']
# (8, 1) ['E', 'S']
# (8, 2) ['N', 'E']
# (8, 3) ['S', 'W']
# (8, 4) ['N', 'E']
# (8, 5) ['S']
# (8, 6) ['N', 'S']
# (8, 7) ['N', 'E']
# (8, 8) ['S', 'W']
# (8, 9) ['N', 'W']
# (9, 0) ['S', 'W']
# (9, 1) ['N', 'W']
# (9, 2) ['S', 'W']
# (9, 3) ['N', 'S']
# (9, 4) ['N', 'S', 'W']
# (9, 5) ['N', 'S']
# (9, 6) ['N', 'S']
# (9, 7) ['N', 'S', 'W']
# (9, 8) ['N', 'S']
# {(0, 0): 'E', (0, 1): 'S', (0, 2): 'S', (0, 3): 'S', (0, 4): 'E', (0, 5): 'S', (0, 6): 'N', (0, 7): 'S', (0, 8): 'E', (0, 9): 'N', (1, 0): 'E', (1, 1): 'S', (1, 2): 'S', (1, 3): 'W', (1, 4): 'S', (1, 5): 'E', (1, 6): 'W', (1, 7): 'E', (1, 8): 'N', (1, 9): 'W', (2, 0): 'W', (2, 1): 'E', (2, 2): 'E', (2, 3): 'E', (2, 4): 'E', (2, 5): 'N', (2, 6): 'E', (2, 7): 'N', (2, 8): 'E', (2, 9): 'N', (3, 0): 'E', (3, 1): 'N', (3, 2): 'W', (3, 3): 'S', (3, 4): 'S', (3, 5): 'E', (3, 6): 'E', (3, 7): 'E', (3, 8): 'S', (3, 9): 'E', (4, 0): 'E', (4, 1): 'S', (4, 2): 'S', (4, 3): 'S', (4, 4): 'E', (4, 5): 'E', (4, 6): 'E', (4, 7): 'E', (4, 8): 'E', (4, 9): 'N', (5, 0): 'E', (5, 1): 'W', (5, 2): 'E', (5, 3): 'N', (5, 4): 'N', (5, 5): 'E', (5, 6): 'W', (5, 7): 'E', (5, 8): 'W', (5, 9): 'N', (6, 0): 'W', (6, 1): 'N', (6, 2): 'S', (6, 3): 'S', (6, 4): 'E', (6, 5): 'S', (6, 6): 'S', (6, 7): 'S', (6, 8): 'N', (6, 9): 'W', (7, 0): 'E', (7, 1): 'S', (7, 2): 'S', (7, 3): 'E', (7, 4): 'S', (7, 5): 'S', (7, 6): 'N', (7, 7): 'N', (7, 8): 'N', (7, 9): 'E', (8, 0): 'W', (8, 1): 'E', (8, 2): 'E', (8, 3): 'S', (8, 4): 'E', (8, 5): 'S', (8, 6): 'N', (8, 7): 'N', (8, 8): 'W', (8, 9): 'N', (9, 0): 'S', (9, 1): 'N', (9, 2): 'S', (9, 3): 'S', (9, 4): 'S', (9, 5): 'S', (9, 6): 'S', (9, 7): 'S', (9, 8): 'S', (9, 9): 'N'}
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /home/yaroslav/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3445: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
