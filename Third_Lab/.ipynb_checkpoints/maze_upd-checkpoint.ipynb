# %%
import numpy as np

from algorithms import QLearning, ValueIteration
from environments import MazeEnv

import matplotlib.pyplot as plt
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.6.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
def get_results(env_size, num_episodes, num_portals, min_eps_rate, min_learning_rate, learning_rate,
                eps_rate, gamma, max_win_streak=100, 
                learning_rate_is_constant=False, eps_rate_is_constant=False, 
                debug=True, render_maze=True, recording_folder='./videos', enable_recording=True):
    
    env = MazeEnv(maze_size=env_size, num_portals=num_portals)
    
    qlearning = QLearning(env=env, num_episodes=num_episodes, min_epsilon_rate=min_eps_rate, 
                          min_learning_rate=min_learning_rate, learning_rate=learning_rate,
                          epsilon_rate=eps_rate, gamma=gamma, max_win_streak=max_win_streak,
                          learning_rate_is_constant=learning_rate_is_constant, 
                          epsilon_rate_is_constant=eps_rate_is_constant, debug=debug, render_maze=render_maze,
                          recording_folder=recording_folder, enable_recording=enable_recording
                         )
    
    total_rewards, total_streaks, steps_qty = qlearning.main()
    
    return total_rewards, total_streaks, steps_qty

# %%
total_rewards, total_streaks, steps_qty = get_results((5, 5), 500, 2, 1e-2, 0.5, 0.1, 0.5, 0.8)
# Out:
# /home/klimchuk/.local/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Trying to monitor an environment which has no 'spec' set. This usually means you did not create it via 'gym.make', and is recommended only for advanced users.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Episode = 0
# t = 82
# Explore rate: 0.800000
# Learning rate: 0.800000
# Streaks: 0
# Total reward: 0.000000
# Average Streaks: 0.000000
# Average Rewards: 0.000000
#
# Episode 0 finished after 82.000000 time steps with total reward = 0.000000 (streak 0).
#
# Episode = 1
# t = 112
# Explore rate: 0.800000
# Learning rate: 0.800000
# Streaks: 0
# Total reward: -180.000000
# Average Streaks: 0.000000
# Average Rewards: -90.000000
#
# Episode 1 finished after 112.000000 time steps with total reward = -180.000000 (streak 0).
#
# Episode = 2
# t = 126
# Explore rate: 0.800000
# Learning rate: 0.800000
# Streaks: 0
# Total reward: -110.000000
# Average Streaks: 0.000000
# Average Rewards: -36.666667
#
# Episode 2 finished after 126.000000 time steps with total reward = -110.000000 (streak 0).
#
# Episode = 3
# t = 111
# Explore rate: 0.800000
# Learning rate: 0.800000
# Streaks: 0
# Total reward: -20.000000
# Average Streaks: 0.000000
# Average Rewards: -5.000000
#
# Episode 3 finished after 111.000000 time steps with total reward = -20.000000 (streak 0).
#
# Episode = 4
# t = 69
# Explore rate: 0.795880
# Learning rate: 0.795880
# Streaks: 0
# Total reward: -40.000000
# Average Streaks: 0.000000
# Average Rewards: -8.000000
#
# Episode 4 finished after 69.000000 time steps with total reward = -40.000000 (streak 0).
#
# Episode = 5
# t = 42
# Explore rate: 0.698970
# Learning rate: 0.698970
# Streaks: 0
# Total reward: -40.000000
# Average Streaks: 0.000000
# Average Rewards: -6.666667
#
# Episode 5 finished after 42.000000 time steps with total reward = -40.000000 (streak 0).
#
# Episode = 6
# t = 21
# Explore rate: 0.619789
# Learning rate: 0.619789
# Streaks: 0
# Total reward: 0.000000
# Average Streaks: 0.000000
# Average Rewards: 0.000000
#
# Episode 6 finished after 21.000000 time steps with total reward = 0.000000 (streak 0).
#
# Episode = 7
# t = 13
# Explore rate: 0.552842
# Learning rate: 0.552842
# Streaks: 1
# Total reward: 70.000000
# Average Streaks: 0.125000
# Average Rewards: 8.750000
#
# Episode 7 finished after 13.000000 time steps with total reward = 70.000000 (streak 1).
#
# Episode = 8
# t = 9
# Explore rate: 0.494850
# Learning rate: 0.500000
# Streaks: 2
# Total reward: 70.000000
# Average Streaks: 0.222222
# Average Rewards: 7.777778
#
# Episode 8 finished after 9.000000 time steps with total reward = 70.000000 (streak 2).
#
# Episode = 9
# t = 13
# Explore rate: 0.443697
# Learning rate: 0.500000
# Streaks: 3
# Total reward: 30.000000
# Average Streaks: 0.300000
# Average Rewards: 3.000000
#
# Episode 9 finished after 13.000000 time steps with total reward = 30.000000 (streak 3).
#
# Episode = 10
# t = 38
# Explore rate: 0.397940
# Learning rate: 0.500000
# Streaks: 4
# Total reward: 50.000000
# Average Streaks: 0.363636
# Average Rewards: 4.545455
#
# Episode 10 finished after 38.000000 time steps with total reward = 50.000000 (streak 4).
#
# Episode = 11
# t = 35
# Explore rate: 0.356547
# Learning rate: 0.500000
# Streaks: 0
# Total reward: 40.000000
# Average Streaks: 0.000000
# Average Rewards: 3.333333
#
# Episode 11 finished after 35.000000 time steps with total reward = 40.000000 (streak 0).
#
# Episode = 12
# t = 8
# Explore rate: 0.318759
# Learning rate: 0.500000
# Streaks: 0
# Total reward: 80.000000
# Average Streaks: 0.000000
# Average Rewards: 6.153846
#
# Episode 12 finished after 8.000000 time steps with total reward = 80.000000 (streak 0).
#
# Episode = 13
# t = 8
# Explore rate: 0.283997
# Learning rate: 0.500000
# Streaks: 1
# Total reward: 80.000000
# Average Streaks: 0.071429
# Average Rewards: 5.714286
#
# Episode 13 finished after 8.000000 time steps with total reward = 80.000000 (streak 1).
#
# Episode = 14
# t = 6
# Explore rate: 0.251812
# Learning rate: 0.500000
# Streaks: 2
# Total reward: 80.000000
# Average Streaks: 0.133333
# Average Rewards: 5.333333
#
# Episode 14 finished after 6.000000 time steps with total reward = 80.000000 (streak 2).
#
# Episode = 15
# t = 6
# Explore rate: 0.221849
# Learning rate: 0.500000
# Streaks: 3
# Total reward: 80.000000
# Average Streaks: 0.187500
# Average Rewards: 5.000000
#
# Episode 15 finished after 6.000000 time steps with total reward = 80.000000 (streak 3).
#
# Episode = 16
# t = 43
# Explore rate: 0.193820
# Learning rate: 0.500000
# Streaks: 4
# Total reward: 60.000000
# Average Streaks: 0.235294
# Average Rewards: 3.529412
#
# Episode 16 finished after 43.000000 time steps with total reward = 60.000000 (streak 4).
#
# Episode = 17
# t = 6
# Explore rate: 0.167491
# Learning rate: 0.500000
# Streaks: 0
# Total reward: 80.000000
# Average Streaks: 0.000000
# Average Rewards: 4.444444
#
# Episode 17 finished after 6.000000 time steps with total reward = 80.000000 (streak 0).
#
# Episode = 18
# t = 7
# Explore rate: 0.142668
# Learning rate: 0.500000
# Streaks: 1
# Total reward: 80.000000
# Average Streaks: 0.052632
# Average Rewards: 4.210526
#
# Episode 18 finished after 7.000000 time steps with total reward = 80.000000 (streak 1).
#
# Episode = 19
# t = 9
# Explore rate: 0.119186
# Learning rate: 0.500000
# Streaks: 2
# Total reward: 80.000000
# Average Streaks: 0.100000
# Average Rewards: 4.000000
#
# Episode 19 finished after 9.000000 time steps with total reward = 80.000000 (streak 2).
#
# Episode = 20
# t = 6
# Explore rate: 0.096910
# Learning rate: 0.500000
# Streaks: 3
# Total reward: 80.000000
# Average Streaks: 0.142857
# Average Rewards: 3.809524
#
# Episode 20 finished after 6.000000 time steps with total reward = 80.000000 (streak 3).
#
# Episode = 21
# t = 6
# Explore rate: 0.075721
# Learning rate: 0.500000
# Streaks: 4
# Total reward: 80.000000
# Average Streaks: 0.181818
# Average Rewards: 3.636364
#
# Episode 21 finished after 6.000000 time steps with total reward = 80.000000 (streak 4).
#
# Episode = 22
# t = 6
# Explore rate: 0.055517
# Learning rate: 0.500000
# Streaks: 5
# Total reward: 80.000000
# Average Streaks: 0.217391
# Average Rewards: 3.478261
#
# Episode 22 finished after 6.000000 time steps with total reward = 80.000000 (streak 5).
#
# Episode = 23
# t = 6
# Explore rate: 0.036212
# Learning rate: 0.500000
# Streaks: 6
# Total reward: 80.000000
# Average Streaks: 0.250000
# Average Rewards: 3.333333
#
# Episode 23 finished after 6.000000 time steps with total reward = 80.000000 (streak 6).
#
# Episode = 24
# t = 6
# Explore rate: 0.017729
# Learning rate: 0.500000
# Streaks: 7
# Total reward: 80.000000
# Average Streaks: 0.280000
# Average Rewards: 3.200000
#
# Episode 24 finished after 6.000000 time steps with total reward = 80.000000 (streak 7).
#
# Episode = 25
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 8
# Total reward: 80.000000
# Average Streaks: 0.307692
# Average Rewards: 3.076923
#
# Episode 25 finished after 6.000000 time steps with total reward = 80.000000 (streak 8).
#
# Episode = 26
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 9
# Total reward: 80.000000
# Average Streaks: 0.333333
# Average Rewards: 2.962963
#
# Episode 26 finished after 6.000000 time steps with total reward = 80.000000 (streak 9).
#
# Episode = 27
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 10
# Total reward: 80.000000
# Average Streaks: 0.357143
# Average Rewards: 2.857143
#
# Episode 27 finished after 6.000000 time steps with total reward = 80.000000 (streak 10).
#
# Episode = 28
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 11
# Total reward: 80.000000
# Average Streaks: 0.379310
# Average Rewards: 2.758621
#
# Episode 28 finished after 6.000000 time steps with total reward = 80.000000 (streak 11).
#
# Episode = 29
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 12
# Total reward: 80.000000
# Average Streaks: 0.400000
# Average Rewards: 2.666667
#
# Episode 29 finished after 6.000000 time steps with total reward = 80.000000 (streak 12).
#
# Episode = 30
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 13
# Total reward: 80.000000
# Average Streaks: 0.419355
# Average Rewards: 2.580645
#
# Episode 30 finished after 6.000000 time steps with total reward = 80.000000 (streak 13).
#
# Episode = 31
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 14
# Total reward: 80.000000
# Average Streaks: 0.437500
# Average Rewards: 2.500000
#
# Episode 31 finished after 6.000000 time steps with total reward = 80.000000 (streak 14).
#
# Episode = 32
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 15
# Total reward: 80.000000
# Average Streaks: 0.454545
# Average Rewards: 2.424242
#
# Episode 32 finished after 6.000000 time steps with total reward = 80.000000 (streak 15).
#
# Episode = 33
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 16
# Total reward: 80.000000
# Average Streaks: 0.470588
# Average Rewards: 2.352941
#
# Episode 33 finished after 6.000000 time steps with total reward = 80.000000 (streak 16).
#
# Episode = 34
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 17
# Total reward: 80.000000
# Average Streaks: 0.485714
# Average Rewards: 2.285714
#
# Episode 34 finished after 6.000000 time steps with total reward = 80.000000 (streak 17).
# Episode = 35
# t = 7
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 18
# Total reward: 70.000000
# Average Streaks: 0.500000
# Average Rewards: 1.944444
#
# Episode 35 finished after 7.000000 time steps with total reward = 70.000000 (streak 18).
#
# Episode = 36
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 19
# Total reward: 80.000000
# Average Streaks: 0.513514
# Average Rewards: 2.162162
#
# Episode 36 finished after 6.000000 time steps with total reward = 80.000000 (streak 19).
#
# Episode = 37
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 20
# Total reward: 80.000000
# Average Streaks: 0.526316
# Average Rewards: 2.105263
#
# Episode 37 finished after 6.000000 time steps with total reward = 80.000000 (streak 20).
#
# Episode = 38
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 21
# Total reward: 80.000000
# Average Streaks: 0.538462
# Average Rewards: 2.051282
#
# Episode 38 finished after 6.000000 time steps with total reward = 80.000000 (streak 21).
#
# Episode = 39
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 22
# Total reward: 80.000000
# Average Streaks: 0.550000
# Average Rewards: 2.000000
#
# Episode 39 finished after 6.000000 time steps with total reward = 80.000000 (streak 22).
#
# Episode = 40
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 23
# Total reward: 80.000000
# Average Streaks: 0.560976
# Average Rewards: 1.951220
#
# Episode 40 finished after 6.000000 time steps with total reward = 80.000000 (streak 23).
#
# Episode = 41
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 24
# Total reward: 80.000000
# Average Streaks: 0.571429
# Average Rewards: 1.904762
#
# Episode 41 finished after 6.000000 time steps with total reward = 80.000000 (streak 24).
#
# Episode = 42
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 25
# Total reward: 80.000000
# Average Streaks: 0.581395
# Average Rewards: 1.860465
#
# Episode 42 finished after 6.000000 time steps with total reward = 80.000000 (streak 25).
#
# Episode = 43
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 26
# Total reward: 80.000000
# Average Streaks: 0.590909
# Average Rewards: 1.818182
#
# Episode 43 finished after 6.000000 time steps with total reward = 80.000000 (streak 26).
#
# Episode = 44
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 27
# Total reward: 80.000000
# Average Streaks: 0.600000
# Average Rewards: 1.777778
#
# Episode 44 finished after 6.000000 time steps with total reward = 80.000000 (streak 27).
#
# Episode = 45
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 28
# Total reward: 80.000000
# Average Streaks: 0.608696
# Average Rewards: 1.739130
#
# Episode 45 finished after 6.000000 time steps with total reward = 80.000000 (streak 28).
#
# Episode = 46
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 29
# Total reward: 80.000000
# Average Streaks: 0.617021
# Average Rewards: 1.702128
#
# Episode 46 finished after 6.000000 time steps with total reward = 80.000000 (streak 29).
#
# Episode = 47
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 30
# Total reward: 80.000000
# Average Streaks: 0.625000
# Average Rewards: 1.666667
#
# Episode 47 finished after 6.000000 time steps with total reward = 80.000000 (streak 30).
#
# Episode = 48
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 31
# Total reward: 80.000000
# Average Streaks: 0.632653
# Average Rewards: 1.632653
#
# Episode 48 finished after 6.000000 time steps with total reward = 80.000000 (streak 31).
#
# Episode = 49
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 32
# Total reward: 80.000000
# Average Streaks: 0.640000
# Average Rewards: 1.600000
#
# Episode 49 finished after 6.000000 time steps with total reward = 80.000000 (streak 32).
#
# Episode = 50
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 33
# Total reward: 80.000000
# Average Streaks: 0.647059
# Average Rewards: 1.568627
#
# Episode 50 finished after 6.000000 time steps with total reward = 80.000000 (streak 33).
#
# Episode = 51
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 34
# Total reward: 80.000000
# Average Streaks: 0.653846
# Average Rewards: 1.538462
#
# Episode 51 finished after 6.000000 time steps with total reward = 80.000000 (streak 34).
#
# Episode = 52
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 35
# Total reward: 80.000000
# Average Streaks: 0.660377
# Average Rewards: 1.509434
#
# Episode 52 finished after 6.000000 time steps with total reward = 80.000000 (streak 35).
#
# Episode = 53
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 36
# Total reward: 80.000000
# Average Streaks: 0.666667
# Average Rewards: 1.481481
#
# Episode 53 finished after 6.000000 time steps with total reward = 80.000000 (streak 36).
#
# Episode = 54
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 37
# Total reward: 80.000000
# Average Streaks: 0.672727
# Average Rewards: 1.454545
#
# Episode 54 finished after 6.000000 time steps with total reward = 80.000000 (streak 37).
#
# Episode = 55
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 38
# Total reward: 80.000000
# Average Streaks: 0.678571
# Average Rewards: 1.428571
#
# Episode 55 finished after 6.000000 time steps with total reward = 80.000000 (streak 38).
#
# Episode = 56
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 39
# Total reward: 80.000000
# Average Streaks: 0.684211
# Average Rewards: 1.403509
#
# Episode 56 finished after 6.000000 time steps with total reward = 80.000000 (streak 39).
#
# Episode = 57
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 40
# Total reward: 80.000000
# Average Streaks: 0.689655
# Average Rewards: 1.379310
#
# Episode 57 finished after 6.000000 time steps with total reward = 80.000000 (streak 40).
#
# Episode = 58
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 41
# Total reward: 80.000000
# Average Streaks: 0.694915
# Average Rewards: 1.355932
#
# Episode 58 finished after 6.000000 time steps with total reward = 80.000000 (streak 41).
#
# Episode = 59
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 42
# Total reward: 80.000000
# Average Streaks: 0.700000
# Average Rewards: 1.333333
#
# Episode 59 finished after 6.000000 time steps with total reward = 80.000000 (streak 42).
#
# Episode = 60
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 43
# Total reward: 80.000000
# Average Streaks: 0.704918
# Average Rewards: 1.311475
#
# Episode 60 finished after 6.000000 time steps with total reward = 80.000000 (streak 43).
#
# Episode = 61
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 44
# Total reward: 80.000000
# Average Streaks: 0.709677
# Average Rewards: 1.290323
#
# Episode 61 finished after 6.000000 time steps with total reward = 80.000000 (streak 44).
#
# Episode = 62
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 45
# Total reward: 80.000000
# Average Streaks: 0.714286
# Average Rewards: 1.269841
#
# Episode 62 finished after 6.000000 time steps with total reward = 80.000000 (streak 45).
#
# Episode = 63
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 46
# Total reward: 80.000000
# Average Streaks: 0.718750
# Average Rewards: 1.250000
#
# Episode 63 finished after 6.000000 time steps with total reward = 80.000000 (streak 46).
#
# Episode = 64
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 47
# Total reward: 80.000000
# Average Streaks: 0.723077
# Average Rewards: 1.230769
#
# Episode 64 finished after 6.000000 time steps with total reward = 80.000000 (streak 47).
#
# Episode = 65
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 48
# Total reward: 80.000000
# Average Streaks: 0.727273
# Average Rewards: 1.212121
#
# Episode 65 finished after 6.000000 time steps with total reward = 80.000000 (streak 48).
#
# Episode = 66
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 49
# Total reward: 80.000000
# Average Streaks: 0.731343
# Average Rewards: 1.194030
#
# Episode 66 finished after 6.000000 time steps with total reward = 80.000000 (streak 49).
#
# Episode = 67
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 50
# Total reward: 80.000000
# Average Streaks: 0.735294
# Average Rewards: 1.176471
#
# Episode 67 finished after 6.000000 time steps with total reward = 80.000000 (streak 50).
#
# Episode = 68
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 51
# Total reward: 80.000000
# Average Streaks: 0.739130
# Average Rewards: 1.159420
#
# Episode 68 finished after 6.000000 time steps with total reward = 80.000000 (streak 51).
# Episode = 69
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 52
# Total reward: 80.000000
# Average Streaks: 0.742857
# Average Rewards: 1.142857
#
# Episode 69 finished after 6.000000 time steps with total reward = 80.000000 (streak 52).
#
# Episode = 70
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 53
# Total reward: 80.000000
# Average Streaks: 0.746479
# Average Rewards: 1.126761
#
# Episode 70 finished after 6.000000 time steps with total reward = 80.000000 (streak 53).
#
# Episode = 71
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 54
# Total reward: 80.000000
# Average Streaks: 0.750000
# Average Rewards: 1.111111
#
# Episode 71 finished after 6.000000 time steps with total reward = 80.000000 (streak 54).
#
# Episode = 72
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 55
# Total reward: 80.000000
# Average Streaks: 0.753425
# Average Rewards: 1.095890
#
# Episode 72 finished after 6.000000 time steps with total reward = 80.000000 (streak 55).
#
# Episode = 73
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 56
# Total reward: 80.000000
# Average Streaks: 0.756757
# Average Rewards: 1.081081
#
# Episode 73 finished after 6.000000 time steps with total reward = 80.000000 (streak 56).
#
# Episode = 74
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 57
# Total reward: 80.000000
# Average Streaks: 0.760000
# Average Rewards: 1.066667
#
# Episode 74 finished after 6.000000 time steps with total reward = 80.000000 (streak 57).
#
# Episode = 75
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 58
# Total reward: 80.000000
# Average Streaks: 0.763158
# Average Rewards: 1.052632
#
# Episode 75 finished after 6.000000 time steps with total reward = 80.000000 (streak 58).
#
# Episode = 76
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 59
# Total reward: 80.000000
# Average Streaks: 0.766234
# Average Rewards: 1.038961
#
# Episode 76 finished after 6.000000 time steps with total reward = 80.000000 (streak 59).
#
# Episode = 77
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 60
# Total reward: 80.000000
# Average Streaks: 0.769231
# Average Rewards: 1.025641
#
# Episode 77 finished after 6.000000 time steps with total reward = 80.000000 (streak 60).
#
# Episode = 78
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 61
# Total reward: 80.000000
# Average Streaks: 0.772152
# Average Rewards: 1.012658
#
# Episode 78 finished after 6.000000 time steps with total reward = 80.000000 (streak 61).
#
# Episode = 79
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 62
# Total reward: 80.000000
# Average Streaks: 0.775000
# Average Rewards: 1.000000
#
# Episode 79 finished after 6.000000 time steps with total reward = 80.000000 (streak 62).
#
# Episode = 80
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 63
# Total reward: 80.000000
# Average Streaks: 0.777778
# Average Rewards: 0.987654
#
# Episode 80 finished after 6.000000 time steps with total reward = 80.000000 (streak 63).
#
# Episode = 81
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 64
# Total reward: 80.000000
# Average Streaks: 0.780488
# Average Rewards: 0.975610
#
# Episode 81 finished after 6.000000 time steps with total reward = 80.000000 (streak 64).
#
# Episode = 82
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 65
# Total reward: 80.000000
# Average Streaks: 0.783133
# Average Rewards: 0.963855
#
# Episode 82 finished after 6.000000 time steps with total reward = 80.000000 (streak 65).
#
# Episode = 83
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 66
# Total reward: 80.000000
# Average Streaks: 0.785714
# Average Rewards: 0.952381
#
# Episode 83 finished after 6.000000 time steps with total reward = 80.000000 (streak 66).
#
# Episode = 84
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 67
# Total reward: 80.000000
# Average Streaks: 0.788235
# Average Rewards: 0.941176
#
# Episode 84 finished after 6.000000 time steps with total reward = 80.000000 (streak 67).
#
# Episode = 85
# t = 7
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 68
# Total reward: 80.000000
# Average Streaks: 0.790698
# Average Rewards: 0.930233
#
# Episode 85 finished after 7.000000 time steps with total reward = 80.000000 (streak 68).
#
# Episode = 86
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 69
# Total reward: 80.000000
# Average Streaks: 0.793103
# Average Rewards: 0.919540
#
# Episode 86 finished after 6.000000 time steps with total reward = 80.000000 (streak 69).
#
# Episode = 87
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 70
# Total reward: 80.000000
# Average Streaks: 0.795455
# Average Rewards: 0.909091
#
# Episode 87 finished after 6.000000 time steps with total reward = 80.000000 (streak 70).
#
# Episode = 88
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 71
# Total reward: 80.000000
# Average Streaks: 0.797753
# Average Rewards: 0.898876
#
# Episode 88 finished after 6.000000 time steps with total reward = 80.000000 (streak 71).
#
# Episode = 89
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 72
# Total reward: 80.000000
# Average Streaks: 0.800000
# Average Rewards: 0.888889
#
# Episode 89 finished after 6.000000 time steps with total reward = 80.000000 (streak 72).
#
# Episode = 90
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 73
# Total reward: 80.000000
# Average Streaks: 0.802198
# Average Rewards: 0.879121
#
# Episode 90 finished after 6.000000 time steps with total reward = 80.000000 (streak 73).
#
# Episode = 91
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 74
# Total reward: 80.000000
# Average Streaks: 0.804348
# Average Rewards: 0.869565
#
# Episode 91 finished after 6.000000 time steps with total reward = 80.000000 (streak 74).
#
# Episode = 92
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 75
# Total reward: 80.000000
# Average Streaks: 0.806452
# Average Rewards: 0.860215
#
# Episode 92 finished after 6.000000 time steps with total reward = 80.000000 (streak 75).
#
# Episode = 93
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 76
# Total reward: 80.000000
# Average Streaks: 0.808511
# Average Rewards: 0.851064
#
# Episode 93 finished after 6.000000 time steps with total reward = 80.000000 (streak 76).
#
# Episode = 94
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 77
# Total reward: 80.000000
# Average Streaks: 0.810526
# Average Rewards: 0.842105
#
# Episode 94 finished after 6.000000 time steps with total reward = 80.000000 (streak 77).
#
# Episode = 95
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 78
# Total reward: 80.000000
# Average Streaks: 0.812500
# Average Rewards: 0.833333
#
# Episode 95 finished after 6.000000 time steps with total reward = 80.000000 (streak 78).
#
# Episode = 96
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 79
# Total reward: 80.000000
# Average Streaks: 0.814433
# Average Rewards: 0.824742
#
# Episode 96 finished after 6.000000 time steps with total reward = 80.000000 (streak 79).
#
# Episode = 97
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 80
# Total reward: 80.000000
# Average Streaks: 0.816327
# Average Rewards: 0.816327
#
# Episode 97 finished after 6.000000 time steps with total reward = 80.000000 (streak 80).
#
# Episode = 98
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 81
# Total reward: 80.000000
# Average Streaks: 0.818182
# Average Rewards: 0.808081
#
# Episode 98 finished after 6.000000 time steps with total reward = 80.000000 (streak 81).
#
# Episode = 99
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 82
# Total reward: 80.000000
# Average Streaks: 0.820000
# Average Rewards: 0.800000
#
# Episode 99 finished after 6.000000 time steps with total reward = 80.000000 (streak 82).
#
# Episode = 100
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 83
# Total reward: 80.000000
# Average Streaks: 0.821782
# Average Rewards: 0.792079
#
# Episode 100 finished after 6.000000 time steps with total reward = 80.000000 (streak 83).
#
# Episode = 101
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 84
# Total reward: 80.000000
# Average Streaks: 0.823529
# Average Rewards: 0.784314
#
# Episode 101 finished after 6.000000 time steps with total reward = 80.000000 (streak 84).
#
# Episode = 102
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 85
# Total reward: 80.000000
# Average Streaks: 0.825243
# Average Rewards: 0.776699
#
# Episode 102 finished after 6.000000 time steps with total reward = 80.000000 (streak 85).
#
# Episode = 103
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 86
# Total reward: 80.000000
# Average Streaks: 0.826923
# Average Rewards: 0.769231
#
# Episode 103 finished after 6.000000 time steps with total reward = 80.000000 (streak 86).
# Episode = 104
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 87
# Total reward: 80.000000
# Average Streaks: 0.828571
# Average Rewards: 0.761905
#
# Episode 104 finished after 6.000000 time steps with total reward = 80.000000 (streak 87).
#
# Episode = 105
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 88
# Total reward: 80.000000
# Average Streaks: 0.830189
# Average Rewards: 0.754717
#
# Episode 105 finished after 6.000000 time steps with total reward = 80.000000 (streak 88).
#
# Episode = 106
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 89
# Total reward: 80.000000
# Average Streaks: 0.831776
# Average Rewards: 0.747664
#
# Episode 106 finished after 6.000000 time steps with total reward = 80.000000 (streak 89).
#
# Episode = 107
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 90
# Total reward: 80.000000
# Average Streaks: 0.833333
# Average Rewards: 0.740741
#
# Episode 107 finished after 6.000000 time steps with total reward = 80.000000 (streak 90).
#
# Episode = 108
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 91
# Total reward: 80.000000
# Average Streaks: 0.834862
# Average Rewards: 0.733945
#
# Episode 108 finished after 6.000000 time steps with total reward = 80.000000 (streak 91).
#
# Episode = 109
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 92
# Total reward: 80.000000
# Average Streaks: 0.836364
# Average Rewards: 0.727273
#
# Episode 109 finished after 6.000000 time steps with total reward = 80.000000 (streak 92).
#
# Episode = 110
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 93
# Total reward: 80.000000
# Average Streaks: 0.837838
# Average Rewards: 0.720721
#
# Episode 110 finished after 6.000000 time steps with total reward = 80.000000 (streak 93).
#
# Episode = 111
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 94
# Total reward: 80.000000
# Average Streaks: 0.839286
# Average Rewards: 0.714286
#
# Episode 111 finished after 6.000000 time steps with total reward = 80.000000 (streak 94).
#
# Episode = 112
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 95
# Total reward: 80.000000
# Average Streaks: 0.840708
# Average Rewards: 0.707965
#
# Episode 112 finished after 6.000000 time steps with total reward = 80.000000 (streak 95).
#
# Episode = 113
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 96
# Total reward: 80.000000
# Average Streaks: 0.842105
# Average Rewards: 0.701754
#
# Episode 113 finished after 6.000000 time steps with total reward = 80.000000 (streak 96).
#
# Episode = 114
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 97
# Total reward: 80.000000
# Average Streaks: 0.843478
# Average Rewards: 0.695652
#
# Episode 114 finished after 6.000000 time steps with total reward = 80.000000 (streak 97).
#
# Episode = 115
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 98
# Total reward: 80.000000
# Average Streaks: 0.844828
# Average Rewards: 0.689655
#
# Episode 115 finished after 6.000000 time steps with total reward = 80.000000 (streak 98).
#
# Episode = 116
# t = 6
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 99
# Total reward: 80.000000
# Average Streaks: 0.846154
# Average Rewards: 0.683761
#
# Episode 116 finished after 6.000000 time steps with total reward = 80.000000 (streak 99).
#
# Episode = 117
# t = 7
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 100
# Total reward: 70.000000
# Average Streaks: 0.847458
# Average Rewards: 0.593220
#
# Episode 117 finished after 7.000000 time steps with total reward = 70.000000 (streak 100).

# %%
len(total_rewards)
# Out:
# 117

# %%
plt.figure(figsize=(10, 5))

plt.plot(total_rewards);

# %%
np.mean(total_rewards)
# Out:
# 70.42735042735043

# %%
def get_results_iteration(env_size, num_portals, gamma, epsilon, small, make_action_proba=1, max_win_streak=100, 
                debug=True, render_maze=True, recording_folder='./videos', enable_recording=True):
    
    env = MazeEnv(maze_size=env_size, num_portals=num_portals)
    
    viter = ValueIteration(env=env, gamma=gamma, epsilon=epsilon, small=small,make_action_proba=make_action_proba,
                               max_win_streak=max_win_streak, debug=debug, render_maze=render_maze,
                               recording_folder=recording_folder, enable_recording=enable_recording
                              )
    
    total_rewards, total_streaks, steps_qty = viter.main()
    
    return total_rewards, total_streaks, steps_qty

# %%
total_rewards, total_streaks, steps_qty = get_results_iteration((10, 10), 5, 0.9, 0.1, 0.01)
# Out:
# /home/klimchuk/.local/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Trying to monitor an environment which has no 'spec' set. This usually means you did not create it via 'gym.make', and is recommended only for advanced users.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# t = 21
# Streaks: 0
# Total reward: -9.618992
# Average Streaks: 0.000000
# Average Rewards: -0.437227
#
# Finished after 21.000000 time steps with total reward = -9.618992 (streak 0).
# t = 26
# Streaks: 1
# Total reward: -2.278110
# Average Streaks: 0.037037
# Average Rewards: -0.084374
#
# Finished after 26.000000 time steps with total reward = -2.278110 (streak 1).
# t = 26
# Streaks: 2
# Total reward: 5.073957
# Average Streaks: 0.074074
# Average Rewards: 0.187924
#
# Finished after 26.000000 time steps with total reward = 5.073957 (streak 2).
# t = 26
# Streaks: 3
# Total reward: 12.436112
# Average Streaks: 0.111111
# Average Rewards: 0.460597
#
# Finished after 26.000000 time steps with total reward = 12.436112 (streak 3).

# %%
np.mean(total_rewards)
# Out:
# -8.355075779295369
