# %%
from simulations import qlearning_main, value_iteration_main
from environments import MazeEnv

import matplotlib.pyplot as plt
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.6.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
def get_results_qlearning(env_size, num_episodes, min_explore_rate, min_learning_rate, learning_rate,
                explore_rate, discount_factor, max_win_streak=100, 
                learning_rate_is_constant=False, explore_rate_is_constant=False, 
                debug=True, render_maze=True, recording_folder='./videos', enable_recording=True):
    
    env = MazeEnv(maze_size=env_size)
    
    total_rewards, total_streaks, steps_qty = qlearning_main(env, num_episodes, min_explore_rate, 
                                                             min_learning_rate,
                                                             learning_rate, explore_rate, discount_factor, 
                                                             max_win_streak, learning_rate_is_constant,
                                                             explore_rate_is_constant, debug, render_maze, 
                                                             recording_folder, enable_recording
                                                            )
    
    return total_rewards, total_streaks, steps_qty

# %%
total_rewards, total_streaks, steps_qty = get_results_qlearning((10, 10), 1000, 1e-2, 0.5, 0.1, 0.5, 0.8)
# Out:
# /home/klimchuk/.local/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Trying to monitor an environment which has no 'spec' set. This usually means you did not create it via 'gym.make', and is recommended only for advanced users.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Episode = 0
# t = 933
# Explore rate: 0.800000
# Learning rate: 0.800000
# Streaks: 0
# Total reward: 0.067000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 0 finished after 933.000000 time steps with total reward = 0.067000 (streak 0).
#
# Episode = 1
# t = 1062
# Explore rate: 0.800000
# Learning rate: 0.800000
# Streaks: 0
# Total reward: -0.062000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 1 finished after 1062.000000 time steps with total reward = -0.062000 (streak 0).
#
# Episode = 2
# t = 251
# Explore rate: 0.800000
# Learning rate: 0.800000
# Streaks: 0
# Total reward: 0.749000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 2 finished after 251.000000 time steps with total reward = 0.749000 (streak 0).
#
# Episode = 3
# t = 1317
# Explore rate: 0.800000
# Learning rate: 0.800000
# Streaks: 0
# Total reward: -0.317000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 3 finished after 1317.000000 time steps with total reward = -0.317000 (streak 0).
#
# Episode = 4
# t = 424
# Explore rate: 0.800000
# Learning rate: 0.800000
# Streaks: 0
# Total reward: 0.576000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 4 finished after 424.000000 time steps with total reward = 0.576000 (streak 0).
#
# Episode = 5
# t = 475
# Explore rate: 0.800000
# Learning rate: 0.800000
# Streaks: 0
# Total reward: 0.525000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 5 finished after 475.000000 time steps with total reward = 0.525000 (streak 0).
#
# Episode = 6
# t = 314
# Explore rate: 0.800000
# Learning rate: 0.800000
# Streaks: 0
# Total reward: 0.686000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 6 finished after 314.000000 time steps with total reward = 0.686000 (streak 0).
#
# Episode = 7
# t = 284
# Explore rate: 0.800000
# Learning rate: 0.800000
# Streaks: 0
# Total reward: 0.716000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 7 finished after 284.000000 time steps with total reward = 0.716000 (streak 0).
#
# Episode = 8
# t = 386
# Explore rate: 0.800000
# Learning rate: 0.800000
# Streaks: 0
# Total reward: 0.614000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 8 finished after 386.000000 time steps with total reward = 0.614000 (streak 0).
#
# Episode = 9
# t = 301
# Explore rate: 0.800000
# Learning rate: 0.800000
# Streaks: 0
# Total reward: 0.699000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 9 finished after 301.000000 time steps with total reward = 0.699000 (streak 0).
#
# Episode = 10
# t = 870
# Explore rate: 0.800000
# Learning rate: 0.800000
# Streaks: 0
# Total reward: 0.130000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 10 finished after 870.000000 time steps with total reward = 0.130000 (streak 0).
#
# Episode = 11
# t = 392
# Explore rate: 0.800000
# Learning rate: 0.800000
# Streaks: 0
# Total reward: 0.608000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 11 finished after 392.000000 time steps with total reward = 0.608000 (streak 0).
#
# Episode = 12
# t = 170
# Explore rate: 0.800000
# Learning rate: 0.800000
# Streaks: 0
# Total reward: 0.830000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 12 finished after 170.000000 time steps with total reward = 0.830000 (streak 0).
#
# Episode = 13
# t = 110
# Explore rate: 0.800000
# Learning rate: 0.800000
# Streaks: 0
# Total reward: 0.890000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 13 finished after 110.000000 time steps with total reward = 0.890000 (streak 0).
#
# Episode = 14
# t = 337
# Explore rate: 0.800000
# Learning rate: 0.800000
# Streaks: 0
# Total reward: 0.663000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 14 finished after 337.000000 time steps with total reward = 0.663000 (streak 0).
#
# Episode = 15
# t = 267
# Explore rate: 0.800000
# Learning rate: 0.800000
# Streaks: 0
# Total reward: 0.733000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 15 finished after 267.000000 time steps with total reward = 0.733000 (streak 0).
#
# Episode = 16
# t = 208
# Explore rate: 0.795880
# Learning rate: 0.795880
# Streaks: 0
# Total reward: 0.792000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 16 finished after 208.000000 time steps with total reward = 0.792000 (streak 0).
#
# Episode = 17
# t = 134
# Explore rate: 0.769551
# Learning rate: 0.769551
# Streaks: 0
# Total reward: 0.866000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 17 finished after 134.000000 time steps with total reward = 0.866000 (streak 0).
#
# Episode = 18
# t = 69
# Explore rate: 0.744727
# Learning rate: 0.744727
# Streaks: 0
# Total reward: 0.931000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 18 finished after 69.000000 time steps with total reward = 0.931000 (streak 0).
#
# Episode = 19
# t = 59
# Explore rate: 0.721246
# Learning rate: 0.721246
# Streaks: 1
# Total reward: 0.941000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 19 finished after 59.000000 time steps with total reward = 0.941000 (streak 1).
#
# Episode = 20
# t = 83
# Explore rate: 0.698970
# Learning rate: 0.698970
# Streaks: 2
# Total reward: 0.917000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 20 finished after 83.000000 time steps with total reward = 0.917000 (streak 2).
#
# Episode = 21
# t = 136
# Explore rate: 0.677781
# Learning rate: 0.677781
# Streaks: 3
# Total reward: 0.864000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 21 finished after 136.000000 time steps with total reward = 0.864000 (streak 3).
#
# Episode = 22
# t = 71
# Explore rate: 0.657577
# Learning rate: 0.657577
# Streaks: 0
# Total reward: 0.929000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 22 finished after 71.000000 time steps with total reward = 0.929000 (streak 0).
#
# Episode = 23
# t = 85
# Explore rate: 0.638272
# Learning rate: 0.638272
# Streaks: 1
# Total reward: 0.915000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 23 finished after 85.000000 time steps with total reward = 0.915000 (streak 1).
#
# Episode = 24
# t = 52
# Explore rate: 0.619789
# Learning rate: 0.619789
# Streaks: 2
# Total reward: 0.948000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 24 finished after 52.000000 time steps with total reward = 0.948000 (streak 2).
#
# Episode = 25
# t = 50
# Explore rate: 0.602060
# Learning rate: 0.602060
# Streaks: 3
# Total reward: 0.950000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 25 finished after 50.000000 time steps with total reward = 0.950000 (streak 3).
#
# Episode = 26
# t = 69
# Explore rate: 0.585027
# Learning rate: 0.585027
# Streaks: 4
# Total reward: 0.931000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 26 finished after 69.000000 time steps with total reward = 0.931000 (streak 4).
#
# Episode = 27
# t = 67
# Explore rate: 0.568636
# Learning rate: 0.568636
# Streaks: 5
# Total reward: 0.933000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 27 finished after 67.000000 time steps with total reward = 0.933000 (streak 5).
#
# Episode = 28
# t = 69
# Explore rate: 0.552842
# Learning rate: 0.552842
# Streaks: 6
# Total reward: 0.931000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 28 finished after 69.000000 time steps with total reward = 0.931000 (streak 6).
#
# Episode = 29
# t = 64
# Explore rate: 0.537602
# Learning rate: 0.537602
# Streaks: 7
# Total reward: 0.936000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 29 finished after 64.000000 time steps with total reward = 0.936000 (streak 7).
#
# Episode = 30
# t = 49
# Explore rate: 0.522879
# Learning rate: 0.522879
# Streaks: 8
# Total reward: 0.951000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 30 finished after 49.000000 time steps with total reward = 0.951000 (streak 8).
#
# Episode = 31
# t = 39
# Explore rate: 0.508638
# Learning rate: 0.508638
# Streaks: 9
# Total reward: 0.961000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 31 finished after 39.000000 time steps with total reward = 0.961000 (streak 9).
#
# Episode = 32
# t = 52
# Explore rate: 0.494850
# Learning rate: 0.500000
# Streaks: 10
# Total reward: 0.948000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 32 finished after 52.000000 time steps with total reward = 0.948000 (streak 10).
#
# Episode = 33
# t = 77
# Explore rate: 0.481486
# Learning rate: 0.500000
# Streaks: 11
# Total reward: 0.923000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 33 finished after 77.000000 time steps with total reward = 0.923000 (streak 11).
#
# Episode = 34
# t = 54
# Explore rate: 0.468521
# Learning rate: 0.500000
# Streaks: 12
# Total reward: 0.946000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 34 finished after 54.000000 time steps with total reward = 0.946000 (streak 12).
#
# Episode = 35
# t = 124
# Explore rate: 0.455932
# Learning rate: 0.500000
# Streaks: 13
# Total reward: 0.876000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 35 finished after 124.000000 time steps with total reward = 0.876000 (streak 13).
# Episode = 36
# t = 41
# Explore rate: 0.443697
# Learning rate: 0.500000
# Streaks: 0
# Total reward: 0.959000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 36 finished after 41.000000 time steps with total reward = 0.959000 (streak 0).
#
# Episode = 37
# t = 52
# Explore rate: 0.431798
# Learning rate: 0.500000
# Streaks: 1
# Total reward: 0.948000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 37 finished after 52.000000 time steps with total reward = 0.948000 (streak 1).
#
# Episode = 38
# t = 51
# Explore rate: 0.420216
# Learning rate: 0.500000
# Streaks: 2
# Total reward: 0.949000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 38 finished after 51.000000 time steps with total reward = 0.949000 (streak 2).
#
# Episode = 39
# t = 53
# Explore rate: 0.408935
# Learning rate: 0.500000
# Streaks: 3
# Total reward: 0.947000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 39 finished after 53.000000 time steps with total reward = 0.947000 (streak 3).
#
# Episode = 40
# t = 52
# Explore rate: 0.397940
# Learning rate: 0.500000
# Streaks: 4
# Total reward: 0.948000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 40 finished after 52.000000 time steps with total reward = 0.948000 (streak 4).
#
# Episode = 41
# t = 54
# Explore rate: 0.387216
# Learning rate: 0.500000
# Streaks: 5
# Total reward: 0.946000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 41 finished after 54.000000 time steps with total reward = 0.946000 (streak 5).
#
# Episode = 42
# t = 48
# Explore rate: 0.376751
# Learning rate: 0.500000
# Streaks: 6
# Total reward: 0.952000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 42 finished after 48.000000 time steps with total reward = 0.952000 (streak 6).
#
# Episode = 43
# t = 57
# Explore rate: 0.366532
# Learning rate: 0.500000
# Streaks: 7
# Total reward: 0.943000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 43 finished after 57.000000 time steps with total reward = 0.943000 (streak 7).
#
# Episode = 44
# t = 38
# Explore rate: 0.356547
# Learning rate: 0.500000
# Streaks: 8
# Total reward: 0.962000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 44 finished after 38.000000 time steps with total reward = 0.962000 (streak 8).
#
# Episode = 45
# t = 47
# Explore rate: 0.346787
# Learning rate: 0.500000
# Streaks: 9
# Total reward: 0.953000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 45 finished after 47.000000 time steps with total reward = 0.953000 (streak 9).
#
# Episode = 46
# t = 45
# Explore rate: 0.337242
# Learning rate: 0.500000
# Streaks: 10
# Total reward: 0.955000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 46 finished after 45.000000 time steps with total reward = 0.955000 (streak 10).
#
# Episode = 47
# t = 45
# Explore rate: 0.327902
# Learning rate: 0.500000
# Streaks: 11
# Total reward: 0.955000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 47 finished after 45.000000 time steps with total reward = 0.955000 (streak 11).
#
# Episode = 48
# t = 34
# Explore rate: 0.318759
# Learning rate: 0.500000
# Streaks: 12
# Total reward: 0.966000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 48 finished after 34.000000 time steps with total reward = 0.966000 (streak 12).
#
# Episode = 49
# t = 33
# Explore rate: 0.309804
# Learning rate: 0.500000
# Streaks: 13
# Total reward: 0.967000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 49 finished after 33.000000 time steps with total reward = 0.967000 (streak 13).
#
# Episode = 50
# t = 35
# Explore rate: 0.301030
# Learning rate: 0.500000
# Streaks: 14
# Total reward: 0.965000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 50 finished after 35.000000 time steps with total reward = 0.965000 (streak 14).
#
# Episode = 51
# t = 59
# Explore rate: 0.292430
# Learning rate: 0.500000
# Streaks: 15
# Total reward: 0.941000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 51 finished after 59.000000 time steps with total reward = 0.941000 (streak 15).
#
# Episode = 52
# t = 42
# Explore rate: 0.283997
# Learning rate: 0.500000
# Streaks: 16
# Total reward: 0.958000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 52 finished after 42.000000 time steps with total reward = 0.958000 (streak 16).
#
# Episode = 53
# t = 35
# Explore rate: 0.275724
# Learning rate: 0.500000
# Streaks: 17
# Total reward: 0.965000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 53 finished after 35.000000 time steps with total reward = 0.965000 (streak 17).
#
# Episode = 54
# t = 37
# Explore rate: 0.267606
# Learning rate: 0.500000
# Streaks: 18
# Total reward: 0.963000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 54 finished after 37.000000 time steps with total reward = 0.963000 (streak 18).
#
# Episode = 55
# t = 38
# Explore rate: 0.259637
# Learning rate: 0.500000
# Streaks: 19
# Total reward: 0.962000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 55 finished after 38.000000 time steps with total reward = 0.962000 (streak 19).
#
# Episode = 56
# t = 30
# Explore rate: 0.251812
# Learning rate: 0.500000
# Streaks: 20
# Total reward: 0.970000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 56 finished after 30.000000 time steps with total reward = 0.970000 (streak 20).
#
# Episode = 57
# t = 41
# Explore rate: 0.244125
# Learning rate: 0.500000
# Streaks: 21
# Total reward: 0.959000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 57 finished after 41.000000 time steps with total reward = 0.959000 (streak 21).
#
# Episode = 58
# t = 34
# Explore rate: 0.236572
# Learning rate: 0.500000
# Streaks: 22
# Total reward: 0.966000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 58 finished after 34.000000 time steps with total reward = 0.966000 (streak 22).
#
# Episode = 59
# t = 30
# Explore rate: 0.229148
# Learning rate: 0.500000
# Streaks: 23
# Total reward: 0.970000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 59 finished after 30.000000 time steps with total reward = 0.970000 (streak 23).
#
# Episode = 60
# t = 40
# Explore rate: 0.221849
# Learning rate: 0.500000
# Streaks: 24
# Total reward: 0.960000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 60 finished after 40.000000 time steps with total reward = 0.960000 (streak 24).
#
# Episode = 61
# t = 29
# Explore rate: 0.214670
# Learning rate: 0.500000
# Streaks: 25
# Total reward: 0.971000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 61 finished after 29.000000 time steps with total reward = 0.971000 (streak 25).
#
# Episode = 62
# t = 33
# Explore rate: 0.207608
# Learning rate: 0.500000
# Streaks: 26
# Total reward: 0.967000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 62 finished after 33.000000 time steps with total reward = 0.967000 (streak 26).
#
# Episode = 63
# t = 32
# Explore rate: 0.200659
# Learning rate: 0.500000
# Streaks: 27
# Total reward: 0.968000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 63 finished after 32.000000 time steps with total reward = 0.968000 (streak 27).
#
# Episode = 64
# t = 30
# Explore rate: 0.193820
# Learning rate: 0.500000
# Streaks: 28
# Total reward: 0.970000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 64 finished after 30.000000 time steps with total reward = 0.970000 (streak 28).
#
# Episode = 65
# t = 36
# Explore rate: 0.187087
# Learning rate: 0.500000
# Streaks: 29
# Total reward: 0.964000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 65 finished after 36.000000 time steps with total reward = 0.964000 (streak 29).
#
# Episode = 66
# t = 40
# Explore rate: 0.180456
# Learning rate: 0.500000
# Streaks: 30
# Total reward: 0.960000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 66 finished after 40.000000 time steps with total reward = 0.960000 (streak 30).
#
# Episode = 67
# t = 41
# Explore rate: 0.173925
# Learning rate: 0.500000
# Streaks: 31
# Total reward: 0.959000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 67 finished after 41.000000 time steps with total reward = 0.959000 (streak 31).
#
# Episode = 68
# t = 37
# Explore rate: 0.167491
# Learning rate: 0.500000
# Streaks: 32
# Total reward: 0.963000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 68 finished after 37.000000 time steps with total reward = 0.963000 (streak 32).
#
# Episode = 69
# t = 29
# Explore rate: 0.161151
# Learning rate: 0.500000
# Streaks: 33
# Total reward: 0.971000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 69 finished after 29.000000 time steps with total reward = 0.971000 (streak 33).
#
# Episode = 70
# t = 30
# Explore rate: 0.154902
# Learning rate: 0.500000
# Streaks: 34
# Total reward: 0.970000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 70 finished after 30.000000 time steps with total reward = 0.970000 (streak 34).
#
# Episode = 71
# t = 31
# Explore rate: 0.148742
# Learning rate: 0.500000
# Streaks: 35
# Total reward: 0.969000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 71 finished after 31.000000 time steps with total reward = 0.969000 (streak 35).
# Episode = 72
# t = 29
# Explore rate: 0.142668
# Learning rate: 0.500000
# Streaks: 36
# Total reward: 0.971000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 72 finished after 29.000000 time steps with total reward = 0.971000 (streak 36).
#
# Episode = 73
# t = 40
# Explore rate: 0.136677
# Learning rate: 0.500000
# Streaks: 37
# Total reward: 0.960000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 73 finished after 40.000000 time steps with total reward = 0.960000 (streak 37).
#
# Episode = 74
# t = 30
# Explore rate: 0.130768
# Learning rate: 0.500000
# Streaks: 38
# Total reward: 0.970000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 74 finished after 30.000000 time steps with total reward = 0.970000 (streak 38).
#
# Episode = 75
# t = 34
# Explore rate: 0.124939
# Learning rate: 0.500000
# Streaks: 39
# Total reward: 0.966000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 75 finished after 34.000000 time steps with total reward = 0.966000 (streak 39).
#
# Episode = 76
# t = 32
# Explore rate: 0.119186
# Learning rate: 0.500000
# Streaks: 40
# Total reward: 0.968000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 76 finished after 32.000000 time steps with total reward = 0.968000 (streak 40).
#
# Episode = 77
# t = 27
# Explore rate: 0.113509
# Learning rate: 0.500000
# Streaks: 41
# Total reward: 0.973000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 77 finished after 27.000000 time steps with total reward = 0.973000 (streak 41).
#
# Episode = 78
# t = 28
# Explore rate: 0.107905
# Learning rate: 0.500000
# Streaks: 42
# Total reward: 0.972000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 78 finished after 28.000000 time steps with total reward = 0.972000 (streak 42).
#
# Episode = 79
# t = 28
# Explore rate: 0.102373
# Learning rate: 0.500000
# Streaks: 43
# Total reward: 0.972000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 79 finished after 28.000000 time steps with total reward = 0.972000 (streak 43).
#
# Episode = 80
# t = 30
# Explore rate: 0.096910
# Learning rate: 0.500000
# Streaks: 44
# Total reward: 0.970000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 80 finished after 30.000000 time steps with total reward = 0.970000 (streak 44).
#
# Episode = 81
# t = 30
# Explore rate: 0.091515
# Learning rate: 0.500000
# Streaks: 45
# Total reward: 0.970000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 81 finished after 30.000000 time steps with total reward = 0.970000 (streak 45).
#
# Episode = 82
# t = 37
# Explore rate: 0.086186
# Learning rate: 0.500000
# Streaks: 46
# Total reward: 0.963000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 82 finished after 37.000000 time steps with total reward = 0.963000 (streak 46).
#
# Episode = 83
# t = 27
# Explore rate: 0.080922
# Learning rate: 0.500000
# Streaks: 47
# Total reward: 0.973000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 83 finished after 27.000000 time steps with total reward = 0.973000 (streak 47).
#
# Episode = 84
# t = 30
# Explore rate: 0.075721
# Learning rate: 0.500000
# Streaks: 48
# Total reward: 0.970000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 84 finished after 30.000000 time steps with total reward = 0.970000 (streak 48).
#
# Episode = 85
# t = 29
# Explore rate: 0.070581
# Learning rate: 0.500000
# Streaks: 49
# Total reward: 0.971000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 85 finished after 29.000000 time steps with total reward = 0.971000 (streak 49).
#
# Episode = 86
# t = 27
# Explore rate: 0.065502
# Learning rate: 0.500000
# Streaks: 50
# Total reward: 0.973000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 86 finished after 27.000000 time steps with total reward = 0.973000 (streak 50).
#
# Episode = 87
# t = 26
# Explore rate: 0.060481
# Learning rate: 0.500000
# Streaks: 51
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 87 finished after 26.000000 time steps with total reward = 0.974000 (streak 51).
#
# Episode = 88
# t = 26
# Explore rate: 0.055517
# Learning rate: 0.500000
# Streaks: 52
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 88 finished after 26.000000 time steps with total reward = 0.974000 (streak 52).
#
# Episode = 89
# t = 26
# Explore rate: 0.050610
# Learning rate: 0.500000
# Streaks: 53
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 89 finished after 26.000000 time steps with total reward = 0.974000 (streak 53).
#
# Episode = 90
# t = 27
# Explore rate: 0.045757
# Learning rate: 0.500000
# Streaks: 54
# Total reward: 0.973000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 90 finished after 27.000000 time steps with total reward = 0.973000 (streak 54).
#
# Episode = 91
# t = 26
# Explore rate: 0.040959
# Learning rate: 0.500000
# Streaks: 55
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 91 finished after 26.000000 time steps with total reward = 0.974000 (streak 55).
#
# Episode = 92
# t = 27
# Explore rate: 0.036212
# Learning rate: 0.500000
# Streaks: 56
# Total reward: 0.973000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 92 finished after 27.000000 time steps with total reward = 0.973000 (streak 56).
#
# Episode = 93
# t = 26
# Explore rate: 0.031517
# Learning rate: 0.500000
# Streaks: 57
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 93 finished after 26.000000 time steps with total reward = 0.974000 (streak 57).
#
# Episode = 94
# t = 26
# Explore rate: 0.026872
# Learning rate: 0.500000
# Streaks: 58
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 94 finished after 26.000000 time steps with total reward = 0.974000 (streak 58).
#
# Episode = 95
# t = 28
# Explore rate: 0.022276
# Learning rate: 0.500000
# Streaks: 59
# Total reward: 0.972000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 95 finished after 28.000000 time steps with total reward = 0.972000 (streak 59).
#
# Episode = 96
# t = 26
# Explore rate: 0.017729
# Learning rate: 0.500000
# Streaks: 60
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 96 finished after 26.000000 time steps with total reward = 0.974000 (streak 60).
#
# Episode = 97
# t = 26
# Explore rate: 0.013228
# Learning rate: 0.500000
# Streaks: 61
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 97 finished after 26.000000 time steps with total reward = 0.974000 (streak 61).
#
# Episode = 98
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 62
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 98 finished after 26.000000 time steps with total reward = 0.974000 (streak 62).
#
# Episode = 99
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 63
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 99 finished after 26.000000 time steps with total reward = 0.974000 (streak 63).
#
# Episode = 100
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 64
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 100 finished after 26.000000 time steps with total reward = 0.974000 (streak 64).
#
# Episode = 101
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 65
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 101 finished after 26.000000 time steps with total reward = 0.974000 (streak 65).
#
# Episode = 102
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 66
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 102 finished after 26.000000 time steps with total reward = 0.974000 (streak 66).
#
# Episode = 103
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 67
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 103 finished after 26.000000 time steps with total reward = 0.974000 (streak 67).
#
# Episode = 104
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 68
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 104 finished after 26.000000 time steps with total reward = 0.974000 (streak 68).
#
# Episode = 105
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 69
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 105 finished after 26.000000 time steps with total reward = 0.974000 (streak 69).
#
# Episode = 106
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 70
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 106 finished after 26.000000 time steps with total reward = 0.974000 (streak 70).
#
# Episode = 107
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 71
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 107 finished after 26.000000 time steps with total reward = 0.974000 (streak 71).
# Episode = 108
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 72
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 108 finished after 26.000000 time steps with total reward = 0.974000 (streak 72).
#
# Episode = 109
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 73
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 109 finished after 26.000000 time steps with total reward = 0.974000 (streak 73).
#
# Episode = 110
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 74
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 110 finished after 26.000000 time steps with total reward = 0.974000 (streak 74).
#
# Episode = 111
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 75
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 111 finished after 26.000000 time steps with total reward = 0.974000 (streak 75).
#
# Episode = 112
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 76
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 112 finished after 26.000000 time steps with total reward = 0.974000 (streak 76).
#
# Episode = 113
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 77
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 113 finished after 26.000000 time steps with total reward = 0.974000 (streak 77).
#
# Episode = 114
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 78
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 114 finished after 26.000000 time steps with total reward = 0.974000 (streak 78).
#
# Episode = 115
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 79
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 115 finished after 26.000000 time steps with total reward = 0.974000 (streak 79).
#
# Episode = 116
# t = 27
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 80
# Total reward: 0.973000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 116 finished after 27.000000 time steps with total reward = 0.973000 (streak 80).
#
# Episode = 117
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 81
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 117 finished after 26.000000 time steps with total reward = 0.974000 (streak 81).
#
# Episode = 118
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 82
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 118 finished after 26.000000 time steps with total reward = 0.974000 (streak 82).
#
# Episode = 119
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 83
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 119 finished after 26.000000 time steps with total reward = 0.974000 (streak 83).
#
# Episode = 120
# t = 28
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 84
# Total reward: 0.972000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 120 finished after 28.000000 time steps with total reward = 0.972000 (streak 84).
#
# Episode = 121
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 85
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 121 finished after 26.000000 time steps with total reward = 0.974000 (streak 85).
#
# Episode = 122
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 86
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 122 finished after 26.000000 time steps with total reward = 0.974000 (streak 86).
#
# Episode = 123
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 87
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 123 finished after 26.000000 time steps with total reward = 0.974000 (streak 87).
#
# Episode = 124
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 88
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 124 finished after 26.000000 time steps with total reward = 0.974000 (streak 88).
#
# Episode = 125
# t = 28
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 89
# Total reward: 0.972000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 125 finished after 28.000000 time steps with total reward = 0.972000 (streak 89).
#
# Episode = 126
# t = 27
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 90
# Total reward: 0.973000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 126 finished after 27.000000 time steps with total reward = 0.973000 (streak 90).
#
# Episode = 127
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 91
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 127 finished after 26.000000 time steps with total reward = 0.974000 (streak 91).
#
# Episode = 128
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 92
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 128 finished after 26.000000 time steps with total reward = 0.974000 (streak 92).
#
# Episode = 129
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 93
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 129 finished after 26.000000 time steps with total reward = 0.974000 (streak 93).
#
# Episode = 130
# t = 27
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 94
# Total reward: 0.973000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 130 finished after 27.000000 time steps with total reward = 0.973000 (streak 94).
#
# Episode = 131
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 95
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 131 finished after 26.000000 time steps with total reward = 0.974000 (streak 95).
#
# Episode = 132
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 96
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 132 finished after 26.000000 time steps with total reward = 0.974000 (streak 96).
#
# Episode = 133
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 97
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 133 finished after 26.000000 time steps with total reward = 0.974000 (streak 97).
#
# Episode = 134
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 98
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 134 finished after 26.000000 time steps with total reward = 0.974000 (streak 98).
#
# Episode = 135
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 99
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 135 finished after 26.000000 time steps with total reward = 0.974000 (streak 99).
#
# Episode = 136
# t = 26
# Explore rate: 0.010000
# Learning rate: 0.500000
# Streaks: 100
# Total reward: 0.974000
# Average Streaks: 0
# Average Rewards: 0
#
# Episode 136 finished after 26.000000 time steps with total reward = 0.974000 (streak 100).

# %%
len(total_rewards)
# Out:
# 136

# %%
plt.figure(figsize=(10, 5))

plt.plot(total_rewards);

# %%
def get_results_value_iteration(env_size, gamma, epsilon, make_action_proba, max_win_streak=100, 
                debug=True, render_maze=True, recording_folder='./videos', enable_recording=True):
    
    env = MazeEnv(maze_size=env_size)
    
    total_rewards, total_streaks, steps_qty = value_iteration_main(env, gamma, epsilon, make_action_proba,
                                                                   max_win_streak, debug, render_maze,
                                                                   recording_folder, enable_recording
                                                                  )
    
    return total_rewards, total_streaks, steps_qty

# %%
total_rewards, total_streaks, steps_qty = get_results_value_iteration((10, 10), 0.9, 0.01, 1)
# Out:
# /home/klimchuk/.local/lib/python3.6/site-packages/gym/logger.py:30: UserWarning: WARN: Trying to monitor an environment which has no 'spec' set. This usually means you did not create it via 'gym.make', and is recommended only for advanced users.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Iteration: 19
# t = 29
# Streaks: 0
# Total reward: 2.912348
# Average Streaks: 0.000000
# Average Rewards: 0.097078
#
# Finished after 29.000000 time steps with total reward = 2.912348 (streak 0).
# Iteration: 25
# t = 39
# Streaks: 1
# Total reward: 10.027123
# Average Streaks: 0.025000
# Average Rewards: 0.250678
#
# Finished after 39.000000 time steps with total reward = 10.027123 (streak 1).
# Iteration: 28
# t = 43
# Streaks: 2
# Total reward: 18.601230
# Average Streaks: 0.045455
# Average Rewards: 0.422755
#
# Finished after 43.000000 time steps with total reward = 18.601230 (streak 2).

# %%
np.mean(total_rewards)
# Out:
# 0.23778413456516395
